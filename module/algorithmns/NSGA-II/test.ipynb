# %%
##  Mutation

# %%
from pymoo.algorithms.nsga2 import NSGA2
from pymoo.factory import get_sampling, get_crossover, get_mutation, get_termination, get_selection
from pymoo.factory import get_problem
from pymoo.optimize import minimize
from pymoo.visualization.scatter import Scatter
from pymoo.util.termination.default import MultiObjectiveDefaultTermination
from pymoo.factory import get_performance_indicator
import numpy as np
import time
import sys
import os 

#for path in sys.path:
#    print(path)

problem_list = ['BNH', 'OSY', 'TNK', 'Truss2D', 'Welded_Beam', 'zdt1','ZDT2','ZDT3','ZDT4','ZDT5','ZDT6']

#!select problem here
select_problem_list = ['BNH', 'OSY', 'TNK','Truss2D','Welded_Beam']

#eta list
eta_list = [1,2,5,7,9,10,13,16,18,20,25,27,30 ]
problem_parameter_dict = {}

for problem_name in select_problem_list:
    res_dict = {}

    for eta in eta_list:
        print('\n\n')
        print('='*60)

        p = get_problem(problem_name)
        print('problem is:\n',p)
        
        #algorithm parameters
        algorithm = NSGA2( 
        n_offspring = 5,
        crossover=get_crossover("real_sbx", prob=0.4, eta=15),
        mutation=get_mutation("real_pm", eta=eta), #!! eta
        eliminate_duplicates=True
    )

    #set time 
        start = time.time()
        res = minimize(p,
                algorithm,
                seed=1,
                save_history=True,
                verbose=False)
                
        print('Time elapsed for solving problem: ', time.time() - start, ' seconds\n')
        #problem_dict[problem_name] = {'Solution':np.array(res.X), 'Obj_value':np.array(res.F), 'CV':np.array(res.CV)}
        
        
    #    print("Best solution found: {}".format(res.X.shape)) #pareto solution set 
    #    print("Function value: {}".format(res.F.shape)) #object function value 
    #    print("Constraint violation: {}".format(res.CV.shape)) 
        #join directory 
        
        path = os.path.join(os.getcwd(), 'Result','Algorithmn_Result', 'NAGA-II' )
        
        pf = p.pareto_front()
        if pf is not None:
            gd = get_performance_indicator("gd", pf)
            print("GD", gd.calc(res.F))
            res_dict[str(eta)] = gd.calc(res.F)
        
        try:
            os.makedirs(path)
        except OSError:
            print ("Creation of the directory %s failed" % path)
        else:
            print ("Successfully created the directory %s" % path)
        
        best_solution_path = path + '/NSGA-II_' + str(problem_name)+'_mutation_' + str(eta) + '_X'
        objective_value_path= path + '/NSGA-II_' + str(problem_name) + '_mutation_' +str(eta) + '_F'
        
        

        print(best_solution_path)

        with open(best_solution_path, 'w+') as f:  # infeasible point, outside feasible domain
            print(res.X, sep=' ', file=f)

        with open(objective_value_path, 'w+') as f:  # infeasible point, outside feasible domain
            print(res.F, sep=' ', file=f)


    sorted_dict = dict(sorted(res_dict.items(),
                        key=lambda item: item[1],
                        reverse=False)) 
    problem_parameter_dict[problem_name] = sorted_dict
    print('eta is ', eta)
    
    print(sorted_dict)

print('-'*60)
print('\n!!!!!!Find the best parameter here !!!!!\n')
for i in problem_parameter_dict.keys():
    print(i,problem_parameter_dict[i])
    print('\n')
# Out:
# s/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_TNK_mutation_7_X
#
#
#
# ============================================================
# problem is:
#  # name: TNK
# # n_var: 2
# # n_obj: 2
# # n_constr: 2
#
# Time elapsed for solving problem:  0.6227078437805176  seconds
#
# GD 0.006070845782544318
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_TNK_mutation_9_X
#
#
#
# ============================================================
# problem is:
#  # name: TNK
# # n_var: 2
# # n_obj: 2
# # n_constr: 2
#
# Time elapsed for solving problem:  0.8812389373779297  seconds
#
# GD 0.004984500916732801
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_TNK_mutation_10_X
#
#
#
# ============================================================
# problem is:
#  # name: TNK
# # n_var: 2
# # n_obj: 2
# # n_constr: 2
#
# Time elapsed for solving problem:  1.0171856880187988  seconds
#
# GD 0.005281368116340357
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_TNK_mutation_13_X
#
#
#
# ============================================================
# problem is:
#  # name: TNK
# # n_var: 2
# # n_obj: 2
# # n_constr: 2
#
# Time elapsed for solving problem:  0.4600226879119873  seconds
#
# GD 0.00721224658199126
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_TNK_mutation_16_X
#
#
#
# ============================================================
# problem is:
#  # name: TNK
# # n_var: 2
# # n_obj: 2
# # n_constr: 2
#
# Time elapsed for solving problem:  0.6585168838500977  seconds
#
# GD 0.006943104396530786
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_TNK_mutation_18_X
#
#
#
# ============================================================
# problem is:
#  # name: TNK
# # n_var: 2
# # n_obj: 2
# # n_constr: 2
#
# Time elapsed for solving problem:  0.7041270732879639  seconds
#
# GD 0.004692271721575891
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_TNK_mutation_20_X
#
#
#
# ============================================================
# problem is:
#  # name: TNK
# # n_var: 2
# # n_obj: 2
# # n_constr: 2
#
# Time elapsed for solving problem:  1.0643508434295654  seconds
#
# GD 0.004702878764678306
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_TNK_mutation_25_X
#
#
#
# ============================================================
# problem is:
#  # name: TNK
# # n_var: 2
# # n_obj: 2
# # n_constr: 2
#
# Time elapsed for solving problem:  0.821159839630127  seconds
#
# GD 0.004725986723733238
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_TNK_mutation_27_X
#
#
#
# ============================================================
# problem is:
#  # name: TNK
# # n_var: 2
# # n_obj: 2
# # n_constr: 2
#
# Time elapsed for solving problem:  1.1092979907989502  seconds
#
# GD 0.004097625978514662
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_TNK_mutation_30_X
# eta is  30
# {'30': 0.004097625978514662, '20': 0.004692271721575891, '25': 0.004702878764678306, '27': 0.004725986723733238, '10': 0.004984500916732801, '13': 0.005281368116340357, '2': 0.005614919429490571, '9': 0.006070845782544318, '7': 0.006105746885577605, '5': 0.006843201115772198, '18': 0.006943104396530786, '16': 0.00721224658199126, '1': 0.007271265079496343}
#
#
#
# ============================================================
# problem is:
#  # name: Truss2D
# # n_var: 3
# # n_obj: 2
# # n_constr: 1
#
# Time elapsed for solving problem:  1.4360828399658203  seconds
#
# GD 61.50675740692198
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_Truss2D_mutation_1_X
#
#
#
# ============================================================
# problem is:
#  # name: Truss2D
# # n_var: 3
# # n_obj: 2
# # n_constr: 1
#
# Time elapsed for solving problem:  1.5249238014221191  seconds
#
# GD 75.06730194150005
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_Truss2D_mutation_2_X
#
#
#
# ============================================================
# problem is:
#  # name: Truss2D
# # n_var: 3
# # n_obj: 2
# # n_constr: 1
#
# Time elapsed for solving problem:  2.3892250061035156  seconds
#
# GD 53.06073405364064
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_Truss2D_mutation_5_X
#
#
#
# ============================================================
# problem is:
#  # name: Truss2D
# # n_var: 3
# # n_obj: 2
# # n_constr: 1
#
# Time elapsed for solving problem:  1.6139552593231201  seconds
#
# GD 65.05534362875431
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_Truss2D_mutation_7_X
#
#
#
# ============================================================
# problem is:
#  # name: Truss2D
# # n_var: 3
# # n_obj: 2
# # n_constr: 1
#
# Time elapsed for solving problem:  2.6375598907470703  seconds
#
# GD 54.08803473878979
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_Truss2D_mutation_9_X
#
#
#
# ============================================================
# problem is:
#  # name: Truss2D
# # n_var: 3
# # n_obj: 2
# # n_constr: 1
#
# Time elapsed for solving problem:  1.695631980895996  seconds
#
# GD 50.182495214040884
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_Truss2D_mutation_10_X
#
#
#
# ============================================================
# problem is:
#  # name: Truss2D
# # n_var: 3
# # n_obj: 2
# # n_constr: 1
#
# Time elapsed for solving problem:  2.508389949798584  seconds
#
# GD 58.466214848595534
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_Truss2D_mutation_13_X
#
#
#
# ============================================================
# problem is:
#  # name: Truss2D
# # n_var: 3
# # n_obj: 2
# # n_constr: 1
#
# Time elapsed for solving problem:  2.1084601879119873  seconds
#
# GD 49.96124964936176
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_Truss2D_mutation_16_X
#
#
#
# ============================================================
# problem is:
#  # name: Truss2D
# # n_var: 3
# # n_obj: 2
# # n_constr: 1
#
# Time elapsed for solving problem:  2.1354150772094727  seconds
#
# GD 59.75211608170393
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_Truss2D_mutation_18_X
#
#
#
# ============================================================
# problem is:
#  # name: Truss2D
# # n_var: 3
# # n_obj: 2
# # n_constr: 1
#
# Time elapsed for solving problem:  2.4842820167541504  seconds
#
# GD 52.2616186777751
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_Truss2D_mutation_20_X
#
#
#
# ============================================================
# problem is:
#  # name: Truss2D
# # n_var: 3
# # n_obj: 2
# # n_constr: 1
#
# Time elapsed for solving problem:  2.139292001724243  seconds
#
# GD 62.0273446086321
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_Truss2D_mutation_25_X
#
#
#
# ============================================================
# problem is:
#  # name: Truss2D
# # n_var: 3
# # n_obj: 2
# # n_constr: 1
#
# Time elapsed for solving problem:  1.9697399139404297  seconds
#
# GD 55.82169748737716
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_Truss2D_mutation_27_X
#
#
#
# ============================================================
# problem is:
#  # name: Truss2D
# # n_var: 3
# # n_obj: 2
# # n_constr: 1
#
# Time elapsed for solving problem:  2.6451168060302734  seconds
#
# GD 54.526415689006605
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_Truss2D_mutation_30_X
# eta is  30
# {'16': 49.96124964936176, '10': 50.182495214040884, '20': 52.2616186777751, '5': 53.06073405364064, '9': 54.08803473878979, '30': 54.526415689006605, '27': 55.82169748737716, '13': 58.466214848595534, '18': 59.75211608170393, '1': 61.50675740692198, '25': 62.0273446086321, '7': 65.05534362875431, '2': 75.06730194150005}
#
#
#
# ============================================================
# problem is:
#  # name: WeldedBeam
# # n_var: 4
# # n_obj: 2
# # n_constr: 4
#
# Time elapsed for solving problem:  3.2957680225372314  seconds
#
# GD 0.0461409739919676
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_Welded_Beam_mutation_1_X
#
#
#
# ============================================================
# problem is:
#  # name: WeldedBeam
# # n_var: 4
# # n_obj: 2
# # n_constr: 4
#
# Time elapsed for solving problem:  3.228498935699463  seconds
#
# GD 0.042602092668258845
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_Welded_Beam_mutation_2_X
#
#
#
# ============================================================
# problem is:
#  # name: WeldedBeam
# # n_var: 4
# # n_obj: 2
# # n_constr: 4
#
# Time elapsed for solving problem:  2.1615400314331055  seconds
#
# GD 0.04465527165361321
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_Welded_Beam_mutation_5_X
#
#
#
# ============================================================
# problem is:
#  # name: WeldedBeam
# # n_var: 4
# # n_obj: 2
# # n_constr: 4
#
# Time elapsed for solving problem:  3.0406320095062256  seconds
#
# GD 0.05213975168528353
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_Welded_Beam_mutation_7_X
#
#
#
# ============================================================
# problem is:
#  # name: WeldedBeam
# # n_var: 4
# # n_obj: 2
# # n_constr: 4
#
# Time elapsed for solving problem:  2.7961227893829346  seconds
#
# GD 0.031153885544174545
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_Welded_Beam_mutation_9_X
#
#
#
# ============================================================
# problem is:
#  # name: WeldedBeam
# # n_var: 4
# # n_obj: 2
# # n_constr: 4
#
# Time elapsed for solving problem:  1.9640886783599854  seconds
#
# GD 0.04103879528637422
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_Welded_Beam_mutation_10_X
#
#
#
# ============================================================
# problem is:
#  # name: WeldedBeam
# # n_var: 4
# # n_obj: 2
# # n_constr: 4
#
# Time elapsed for solving problem:  2.9067161083221436  seconds
#
# GD 0.052544374332731916
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_Welded_Beam_mutation_13_X
#
#
#
# ============================================================
# problem is:
#  # name: WeldedBeam
# # n_var: 4
# # n_obj: 2
# # n_constr: 4
#
# Time elapsed for solving problem:  2.1579649448394775  seconds
#
# GD 0.035099578985672
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_Welded_Beam_mutation_16_X
#
#
#
# ============================================================
# problem is:
#  # name: WeldedBeam
# # n_var: 4
# # n_obj: 2
# # n_constr: 4
#
# Time elapsed for solving problem:  1.6682963371276855  seconds
#
# GD 0.06939549550273891
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_Welded_Beam_mutation_18_X
#
#
#
# ============================================================
# problem is:
#  # name: WeldedBeam
# # n_var: 4
# # n_obj: 2
# # n_constr: 4
#
# Time elapsed for solving problem:  2.519829750061035  seconds
#
# GD 0.0449977661405761
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_Welded_Beam_mutation_20_X
#
#
#
# ============================================================
# problem is:
#  # name: WeldedBeam
# # n_var: 4
# # n_obj: 2
# # n_constr: 4
#
# Time elapsed for solving problem:  2.1397101879119873  seconds
#
# GD 0.04582084194566807
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_Welded_Beam_mutation_25_X
#
#
#
# ============================================================
# problem is:
#  # name: WeldedBeam
# # n_var: 4
# # n_obj: 2
# # n_constr: 4
#
# Time elapsed for solving problem:  2.213923215866089  seconds
#
# GD 0.043953869613039924
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_Welded_Beam_mutation_27_X
#
#
#
# ============================================================
# problem is:
#  # name: WeldedBeam
# # n_var: 4
# # n_obj: 2
# # n_constr: 4
#
# Time elapsed for solving problem:  1.6145758628845215  seconds
#
# GD 0.05277642933307246
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_Welded_Beam_mutation_30_X
# eta is  30
# {'9': 0.031153885544174545, '16': 0.035099578985672, '10': 0.04103879528637422, '2': 0.042602092668258845, '27': 0.043953869613039924, '5': 0.04465527165361321, '20': 0.0449977661405761, '25': 0.04582084194566807, '1': 0.0461409739919676, '7': 0.05213975168528353, '13': 0.052544374332731916, '30': 0.05277642933307246, '18': 0.06939549550273891}
# ------------------------------------------------------------
#
# !!!!!!Find the best parameter here !!!!!
#
# BNH {'25': 0.3435785733181836, '2': 0.3617281694404619, '30': 0.36550199741636297, '27': 0.3793624866920521, '18': 0.381263236257211, '13': 0.382812095352101, '16': 0.40227301361118767, '10': 0.405256968632149, '20': 0.4276096031394341, '9': 0.42876558673398846, '5': 0.44265643994652154, '7': 0.45055678690148215, '1': 0.45398789334778367}
#
#
# OSY {'18': 1.2774266459599948, '9': 1.2778095562635006, '10': 1.4611625588441255, '27': 1.5587753365348789, '20': 1.7116144301194935, '2': 1.7578169637772334, '1': 1.9775578485724459, '7': 2.0188819842191488, '30': 2.282204017507522, '25': 2.2916767770350432, '16': 2.3584942678526053, '13': 2.389168367220183, '5': 2.63121973518927}
#
#
# TNK {'30': 0.004097625978514662, '20': 0.004692271721575891, '25': 0.004702878764678306, '27': 0.004725986723733238, '10': 0.004984500916732801, '13': 0.005281368116340357, '2': 0.005614919429490571, '9': 0.006070845782544318, '7': 0.006105746885577605, '5': 0.006843201115772198, '18': 0.006943104396530786, '16': 0.00721224658199126, '1': 0.007271265079496343}
#
#
# Truss2D {'16': 49.96124964936176, '10': 50.182495214040884, '20': 52.2616186777751, '5': 53.06073405364064, '9': 54.08803473878979, '30': 54.526415689006605, '27': 55.82169748737716, '13': 58.466214848595534, '18': 59.75211608170393, '1': 61.50675740692198, '25': 62.0273446086321, '7': 65.05534362875431, '2': 75.06730194150005}
#
#
# Welded_Beam {'9': 0.031153885544174545, '16': 0.035099578985672, '10': 0.04103879528637422, '2': 0.042602092668258845, '27': 0.043953869613039924, '5': 0.04465527165361321, '20': 0.0449977661405761, '25': 0.04582084194566807, '1': 0.0461409739919676, '7': 0.05213975168528353, '13': 0.052544374332731916, '30': 0.05277642933307246, '18': 0.06939549550273891}

# %% [markdown]
# ## Crossover

# %%
from pymoo.algorithms.nsga2 import NSGA2
from pymoo.factory import get_sampling, get_crossover, get_mutation, get_termination
from pymoo.factory import get_problem
from pymoo.optimize import minimize
from pymoo.visualization.scatter import Scatter
from pymoo.util.termination.default import MultiObjectiveDefaultTermination
from pymoo.factory import get_performance_indicator
import numpy as np
import time
import sys
import os 

#for path in sys.path:
#    print(path)

problem_list = ['BNH', 'OSY', 'TNK', 'Truss2D', 'Welded_Beam', 'zdt1','ZDT2','ZDT3','ZDT4','ZDT5','ZDT6']

#!select problem here
select_problem_list = ['BNH', 'OSY', 'TNK','Truss2D','Welded_Beam']


problem_parameter_dict = {}

#! set generation times list here
####!!!!!!!!!!!
pro_list = np.linspace(0,1,50) #from 0 to 1, 50 data points

for problem_name in select_problem_list:
    res_dict = {}

    for pro in pro_list:
        print('\n\n')
        print('='*60)

        p = get_problem(problem_name)
        print('problem is:\n',p)
        
        #algorithm parameters
        algorithm = NSGA2( 
        n_offspring = 5,
        crossover=get_crossover("real_sbx", prob=pro, eta=25), #!parameters
        mutation=get_mutation("real_pm", eta=20),
        eliminate_duplicates=True
    )

    #set time 
        start = time.time()
        res = minimize(p,
                algorithm,
                seed=1,
                save_history=True,
                verbose=False)
                
        print('Time elapsed for solving problem: ', time.time() - start, ' seconds\n')
        #problem_dict[problem_name] = {'Solution':np.array(res.X), 'Obj_value':np.array(res.F), 'CV':np.array(res.CV)}
        print('crossover_real_sbx_probility', pro)
        
    #    print("Best solution found: {}".format(res.X.shape)) #pareto solution set 
    #    print("Function value: {}".format(res.F.shape)) #object function value 
    #    print("Constraint violation: {}".format(res.CV.shape)) 
        #join directory 
        
        path = os.path.join(os.getcwd(), 'Result','Algorithmn_Result', 'NAGA-II' )
        pf = p.pareto_front()
        if pf is not None:
            gd = get_performance_indicator("gd", pf)
            print("GD", gd.calc(res.F))
            res_dict[str(pro)] = gd.calc(res.F)
        
        try:
            os.makedirs(path)
        except OSError:
            print ("Creation of the directory %s failed" % path)
        else:
            print ("Successfully created the directory %s" % path)
        
        best_solution_path = path + '/NSGA-II_' + str(problem_name)+'_crossover_proba_' + str(pro) + '_X'
        objective_value_path= path + '/NSGA-II_' + str(problem_name) + '_crossover_proba_' +str(pro) + '_F'
        
    

        print(best_solution_path)
    '''
        with open(best_solution_path, 'w+') as f:  # infeasible point, outside feasible domain
            print(res.X, sep=' ', file=f)

        with open(objective_value_path, 'w+') as f:  # infeasible point, outside feasible domain
            print(res.F, sep=' ', file=f)

    '''
    sorted_dict = dict(sorted(res_dict.items(),
                        key=lambda item: item[1],
                        reverse=False)) 
    problem_parameter_dict[problem_name] = sorted_dict
    
    

print('-'*60)
print('\n!!!!!!Find the best parameter here !!!!!\n')
for i in problem_parameter_dict.keys():
    print(i,problem_parameter_dict[i])
    print('\n')
# Out:
# .037324514639552324
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_Welded_Beam_crossover_proba_0.673469387755102_X
#
#
#
# ============================================================
# problem is:
#  # name: WeldedBeam
# # n_var: 4
# # n_obj: 2
# # n_constr: 4
#
# Time elapsed for solving problem:  2.958815097808838  seconds
#
# crossover_real_sbx_probility 0.6938775510204082
# GD 0.04175819114061847
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_Welded_Beam_crossover_proba_0.6938775510204082_X
#
#
#
# ============================================================
# problem is:
#  # name: WeldedBeam
# # n_var: 4
# # n_obj: 2
# # n_constr: 4
#
# Time elapsed for solving problem:  2.6904289722442627  seconds
#
# crossover_real_sbx_probility 0.7142857142857142
# GD 0.05073447214646647
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_Welded_Beam_crossover_proba_0.7142857142857142_X
#
#
#
# ============================================================
# problem is:
#  # name: WeldedBeam
# # n_var: 4
# # n_obj: 2
# # n_constr: 4
#
# Time elapsed for solving problem:  1.0647790431976318  seconds
#
# crossover_real_sbx_probility 0.7346938775510203
# GD 0.05604960633590483
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_Welded_Beam_crossover_proba_0.7346938775510203_X
#
#
#
# ============================================================
# problem is:
#  # name: WeldedBeam
# # n_var: 4
# # n_obj: 2
# # n_constr: 4
#
# Time elapsed for solving problem:  1.790071964263916  seconds
#
# crossover_real_sbx_probility 0.7551020408163265
# GD 0.038906336450799356
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_Welded_Beam_crossover_proba_0.7551020408163265_X
#
#
#
# ============================================================
# problem is:
#  # name: WeldedBeam
# # n_var: 4
# # n_obj: 2
# # n_constr: 4
#
# Time elapsed for solving problem:  3.723114013671875  seconds
#
# crossover_real_sbx_probility 0.7755102040816326
# GD 0.03812840881295422
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_Welded_Beam_crossover_proba_0.7755102040816326_X
#
#
#
# ============================================================
# problem is:
#  # name: WeldedBeam
# # n_var: 4
# # n_obj: 2
# # n_constr: 4
#
# Time elapsed for solving problem:  2.2272531986236572  seconds
#
# crossover_real_sbx_probility 0.7959183673469387
# GD 0.05018289039880496
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_Welded_Beam_crossover_proba_0.7959183673469387_X
#
#
#
# ============================================================
# problem is:
#  # name: WeldedBeam
# # n_var: 4
# # n_obj: 2
# # n_constr: 4
#
# Time elapsed for solving problem:  1.4230740070343018  seconds
#
# crossover_real_sbx_probility 0.8163265306122448
# GD 0.045738570263114335
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_Welded_Beam_crossover_proba_0.8163265306122448_X
#
#
#
# ============================================================
# problem is:
#  # name: WeldedBeam
# # n_var: 4
# # n_obj: 2
# # n_constr: 4
#
# Time elapsed for solving problem:  2.1556570529937744  seconds
#
# crossover_real_sbx_probility 0.836734693877551
# GD 0.037640493803367786
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_Welded_Beam_crossover_proba_0.836734693877551_X
#
#
#
# ============================================================
# problem is:
#  # name: WeldedBeam
# # n_var: 4
# # n_obj: 2
# # n_constr: 4
#
# Time elapsed for solving problem:  1.6477079391479492  seconds
#
# crossover_real_sbx_probility 0.8571428571428571
# GD 0.049740710170821247
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_Welded_Beam_crossover_proba_0.8571428571428571_X
#
#
#
# ============================================================
# problem is:
#  # name: WeldedBeam
# # n_var: 4
# # n_obj: 2
# # n_constr: 4
#
# Time elapsed for solving problem:  0.885505199432373  seconds
#
# crossover_real_sbx_probility 0.8775510204081632
# GD 0.04800259462240511
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_Welded_Beam_crossover_proba_0.8775510204081632_X
#
#
#
# ============================================================
# problem is:
#  # name: WeldedBeam
# # n_var: 4
# # n_obj: 2
# # n_constr: 4
#
# Time elapsed for solving problem:
.03766863703821308, '0.2040816326530612': 0.03772191533750701, '0.44897959183673464': 0.037816893869737786, '0.9591836734693877': 0.03790276970235678, '0.7755102040816326': 0.03812840881295422, '0.7551020408163265': 0.038906336450799356, '0.32653061224489793': 0.039167290784643094, '0.2857142857142857': 0.03922323617519502, '0.12244897959183673': 0.039608627947142525, '0.1020408163265306': 0.040403140703907825, '0.5510204081632653': 0.04053108932446957, '0.3877551020408163': 0.041189053959781355, '0.04081632653061224': 0.04122996634676703, '0.061224489795918366': 0.041589553700367245, '0.6938775510204082': 0.04175819114061847, '0.6122448979591836': 0.04193694602447666, '0.26530612244897955': 0.042135524798537126, '0.36734693877551017': 0.0444653729390458, '0.6530612244897959': 0.044962525214374265, '0.8979591836734693': 0.04511746155757008, '0.9183673469387754': 0.04513036618273099, '0.8163265306122448': 0.045738570263114335, '0.5102040816326531': 0.046055705644271985, '0.4693877551020408': 0.04630423902231848, '1.0': 0.0467465821883739, '0.8775510204081632': 0.04800259462240511, '0.5918367346938775': 0.04803001271312851, '0.3469387755102041': 0.04834925475013381, '0.9387755102040816': 0.048545649718469475, '0.16326530612244897': 0.04896921941332125, '0.8571428571428571': 0.049740710170821247, '0.7959183673469387': 0.05018289039880496, '0.7142857142857142': 0.05073447214646647, '0.5714285714285714': 0.05254194575713202, '0.7346938775510203': 0.05604960633590483, '0.22448979591836732': 0.056569762175783224, '0.4081632653061224': 0.06363657353981433, '0.02040816326530612': 0.06384782307393605, '0.6326530612244897': 0.06897114540599766, '0.42857142857142855': 0.07409577756054699}

# %% [markdown]
# ## Generation

# %%
from pymoo.algorithms.nsga2 import NSGA2
from pymoo.factory import get_sampling, get_crossover, get_mutation, get_termination
from pymoo.factory import get_problem
from pymoo.optimize import minimize
from pymoo.visualization.scatter import Scatter
from pymoo.util.termination.default import MultiObjectiveDefaultTermination
from pymoo.factory import get_performance_indicator
import numpy as np
import time
import sys
import os 

#for path in sys.path:
#    print(path)

problem_list = ['BNH', 'OSY', 'TNK', 'Truss2D', 'Welded_Beam', 'zdt1','ZDT2','ZDT3','ZDT4','ZDT5','ZDT6']

#!select problem here
select_problem_list = ['BNH', 'OSY', 'TNK','Truss2D','Welded_Beam']


problem_parameter_dict = {}

#! set generation times list here
####!!!!!!!!!!!
gen_list = list(range(10,2000,50))
for problem_name in select_problem_list:
    res_dict = {}

    for n_gen in gen_list:
        print('\n\n')
        print('='*60)

        p = get_problem(problem_name)
        print('problem is:\n',p)
        
        #algorithm parameters
        algorithm = NSGA2( 
        n_offspring = 20,
        crossover=get_crossover("real_sbx", prob=0.9, eta=15),
        mutation=get_mutation("real_pm", eta=20),
        eliminate_duplicates=True
    )

    #set time 
        start = time.time()
        res = minimize(p,
                algorithm,
                ('n_gen', n_gen),
                seed=1,
                save_history=True,
                verbose=False)
                
        print('Time elapsed for solving problem: ', time.time() - start, ' seconds\n')
        #problem_dict[problem_name] = {'Solution':np.array(res.X), 'Obj_value':np.array(res.F), 'CV':np.array(res.CV)}
        
        print('Generation times', n_gen)
    #    print("Best solution found: {}".format(res.X.shape)) #pareto solution set 
    #    print("Function value: {}".format(res.F.shape)) #object function value 
    #    print("Constraint violation: {}".format(res.CV.shape)) 
        #join directory 
        
        path = os.path.join(os.getcwd(), 'Result','Algorithmn_Result', 'NAGA-II' )
        pf = p.pareto_front()
        if pf is not None:
            gd = get_performance_indicator("gd", pf)
            print("GD", gd.calc(res.F))
            res_dict[str(n_gen)] = gd.calc(res.F)
        
        try:
            os.makedirs(path)
        except OSError:
            print ("Creation of the directory %s failed" % path)
        else:
            print ("Successfully created the directory %s" % path)
        
        best_solution_path = path + '/NSGA-II_' + str(problem_name)+'_generation_' + str(n_gen) + '_X'
        objective_value_path= path + '/NSGA-II_' + str(problem_name) + '_generation_' +str(n_gen) + '_F'
        
        

        print(best_solution_path)

        with open(best_solution_path, 'w+') as f:  # infeasible point, outside feasible domain
            print(res.X, sep=' ', file=f)

        with open(objective_value_path, 'w+') as f:  # infeasible point, outside feasible domain
            print(res.F, sep=' ', file=f)


    sorted_dict = dict(sorted(res_dict.items(),
                        key=lambda item: item[1],
                        reverse=False)) 
    problem_parameter_dict[problem_name] = sorted_dict
    
    print(sorted_dict)

print('-'*60)
print('\n!!!!!!Find the best parameter here !!!!!\n')
for i in problem_parameter_dict.keys():
    print(i,problem_parameter_dict[i])
    print('\n')
# Out:
# ============================================================
# problem is:
#  # name: BNH
# # n_var: 2
# # n_obj: 2
# # n_constr: 2
#
# Time elapsed for solving problem:  0.07755708694458008  seconds
#
# Generation times 10
# GD 0.4066756614383871
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_BNH_generation_10_X
#
#
#
# ============================================================
# problem is:
#  # name: BNH
# # n_var: 2
# # n_obj: 2
# # n_constr: 2
#
# Time elapsed for solving problem:  0.4068729877471924  seconds
#
# Generation times 60
# GD 0.412575447281097
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_BNH_generation_60_X
#
#
#
# ============================================================
# problem is:
#  # name: BNH
# # n_var: 2
# # n_obj: 2
# # n_constr: 2
#
# Time elapsed for solving problem:  0.7538270950317383  seconds
#
# Generation times 110
# GD 0.4319931210896911
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_BNH_generation_110_X
#
#
#
# ============================================================
# problem is:
#  # name: BNH
# # n_var: 2
# # n_obj: 2
# # n_constr: 2
#
# Time elapsed for solving problem:  1.1000351905822754  seconds
#
# Generation times 160
# GD 0.42011101494553066
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_BNH_generation_160_X
#
#
#
# ============================================================
# problem is:
#  # name: BNH
# # n_var: 2
# # n_obj: 2
# # n_constr: 2
#
# Time elapsed for solving problem:  1.8562676906585693  seconds
#
# Generation times 210
# GD 0.40301651242607717
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_BNH_generation_210_X
#
#
#
# ============================================================
# problem is:
#  # name: BNH
# # n_var: 2
# # n_obj: 2
# # n_constr: 2
#
# Time elapsed for solving problem:  1.7921881675720215  seconds
#
# Generation times 260
# GD 0.41485729812380034
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_BNH_generation_260_X
#
#
#
# ============================================================
# problem is:
#  # name: BNH
# # n_var: 2
# # n_obj: 2
# # n_constr: 2
#
# Time elapsed for solving problem:  2.467033863067627  seconds
#
# Generation times 310
# GD 0.4112158665096189
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_BNH_generation_310_X
#
#
#
# ============================================================
# problem is:
#  # name: BNH
# # n_var: 2
# # n_obj: 2
# # n_constr: 2
#
# Time elapsed for solving problem:  2.879023790359497  seconds
#
# Generation times 360
# GD 0.4370449143983148
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_BNH_generation_360_X
#
#
#
# ============================================================
# problem is:
#  # name: BNH
# # n_var: 2
# # n_obj: 2
# # n_constr: 2
#
# Time elapsed for solving problem:  2.8752241134643555  seconds
#
# Generation times 410
# GD 0.3726711216638205
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_BNH_generation_410_X
#
#
#
# ============================================================
# problem is:
#  # name: BNH
# # n_var: 2
# # n_obj: 2
# # n_constr: 2
#
# Time elapsed for solving problem:  3.549333095550537  seconds
#
# Generation times 460
# GD 0.39475980562148194
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_BNH_generation_460_X
#
#
#
# ============================================================
# problem is:
#  # name: BNH
# # n_var: 2
# # n_obj: 2
# # n_constr: 2
#
# Time elapsed for solving problem:  3.9398179054260254  seconds
#
# Generation times 510
# GD 0.41705433056335706
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_BNH_generation_510_X
#
#
#
# ============================================================
# problem is:
#  # name: BNH
# # n_var: 2
# # n_obj: 2
# # n_constr: 2
#
# Time elapsed for solving problem:  4.328197240829468  seconds
#
# Generation times 560
# GD 0.37847102470921856
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_BNH_generation_560_X
#
#
#
# ============================================================
# problem is:
#  # name: BNH
# # n_var: 2
# # n_obj: 2
# # n_constr: 2
#
# Time elapsed for solving problem:  4.700437068939209  seconds
#
# Generation times 610
# GD 0.41348535760583344
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_BNH_generation_610_X
#
#
#
# ============================================================
# problem is:
#  # name: BNH
# # n_var: 2
# # n_obj: 2
# # n_constr: 2
#
# Time elapsed for solving problem:  5.126893997192383  seconds
#
# Generation times 660
# GD 0.3868173446576783
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_BNH_generation_660_X
#
#
#
# ============================================================
# problem is:
#  # name: BNH
# # n_var: 2
# # n_obj: 2
# # n_constr: 2
#
# Time elapsed for solving problem:  5.408469200134277  seconds
#
# Generation times 710
# GD 0.41488375031012936
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_BNH_generation_710_X
#
#
#
# ============================================================
# problem is:
#  # name: BNH
# # n_var: 2
# # n_obj: 2
# # n_constr: 2
#
# Time elapsed for solving problem:  5.7379539012908936  seconds
#
# Generation times 760
# GD 0.3800411202610773
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_BNH_generation_760_X
#
#
#
# ============================================================
# problem is:
#  # name: BNH
# # n_var: 2
# # n_obj: 2
# # n_constr: 2
#
# Time elapsed for solving problem:  6.138149976730347  seconds
#
# Generation times 810
# GD 0.4102968495236827
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_BNH_generation_810_X
#
#
#
# ============================================================
# problem is:
#  # name: BNH
# # n_var: 2
# # n_obj: 2
# # n_constr: 2
#
# Time elapsed for solving problem:  6.465572118759155  seconds
#
# Generation times 860
# GD 0.3701171386528419
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_BNH_generation_860_X
#
#
#
# ============================================================
# problem is:
#  # name: BNH
# # n_var: 2
# # n_obj: 2
# # n_constr: 2
#
# Time elapsed for solving problem:  7.269366025924683  seconds
#
# Generation times 910
# GD 0.42038180091975036
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_BNH_generation_910_X
#
#
#
# ============================================================
# problem is:
#  # name: BNH
# # n_var: 2
# # n_obj: 2
# # n_constr: 2
#
# Time elapsed for solving problem:  7.239840030670166  seconds
#
# Generation times 960
# GD 0.4459692629245602
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_BNH_generation_960_X
#
#
#
# ============================================================
# problem is:
#  # name: BNH
# # n_var: 2
# # n_obj: 2
# # n_constr: 2
#
# Time elapsed for solving problem:  7.581113815307617  seconds
#
# Generation times 1010
# GD 0.41695552560002036
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_BNH_generation_1010_X
#
#
#
# ============================================================
# problem is:
#  # name: BNH
# # n_var: 2
# # n_obj: 2
# # n_constr: 2
#
# Time elapsed for solving problem:  8.193835973739624  seconds
#
# Generation times 1060
# GD 0.37984151427308077
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_BNH_generation_1060_X
#
#
#
# ============================================================
# problem is:
#  # name: BNH
# # n_var: 2
# # n_obj: 2
# # n_constr: 2
#
# Time elapsed for solving problem:  8.06239366531372  seconds
#
# Generation times 1110
# GD 0.4339890735296518
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_BNH_generation_1110_X
#
#
#
# ============================================================
# problem is:
#  # name: BNH
# # n_var: 2
# # n_obj: 2
# # n_constr: 2
#
# Time elapsed for solving problem:  9.02293086051941  seconds
#
# Generation times 1160
# GD 0.4436967580341547
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_BNH_generation_1160_X
#
#
#
# ============================================================
# problem is:
#  # name: BNH
# # n_var: 2
# # n_obj: 2
# # n_constr: 2
#
# Time elapsed for solving problem:  8.800114870071411  seconds
#
# Generation times 1210
# GD 0.4193624469441241
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_BNH_generation_1210_X
#
#
#
# ============================================================
# problem is:
#  # name: BNH
# # n_var: 2
# # n_obj: 2
# # n_constr: 2
#
# Time elapsed for solving problem:  9.208140134811401  seconds
#
# Generation times 1260
# GD 0.37896168845645123
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_BNH_generation_1260_X
#
#
#
# ============================================================
# problem is:
#  # name: BNH
# # n_var: 2
# # n_obj: 2
# # n_constr: 2
#
# Time elapsed for solving problem:  10.074070930480957  seconds
#
# Generation times 1310
# GD 0.3884971327921464
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_BNH_generation_1310_X
#
#
#
# ============================================================
# problem is:
#  # name: BNH
# # n_var: 2
# # n_obj: 2
# # n_constr: 2
#
# Time elapsed for solving problem:  9.912848949432373  seconds
#
# Generation times 1360
# GD 0.40671948828489085
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_BNH_generation_1360_X
#
#
#
# ============================================================
# problem is:
#  # name: BNH
# # n_var: 2
# # n_obj: 2
# # n_constr: 2
#
# Time elapsed for solving problem:  10.790044784545898  seconds
#
# Generation times 1410
# GD 0.39329673742775184
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_BNH_generation_1410_X
#
#
#
# ============================================================
# problem is:
#  # name: BNH
# # n_var: 2
# # n_obj: 2
# # n_constr: 2
#
# Time elapsed for solving problem:  10.647923946380615  seconds
#
# Generation times 1460
# GD 0.3957505480642904
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_BNH_generation_1460_X
#
#
#
# ============================================================
# problem is:
#  # name: BNH
# # n_var: 2
# # n_obj: 2
# # n_constr: 2
#
# Time elapsed for solving problem:  11.490478992462158  seconds
#
# Generation times 1510
# GD 0.40443826228510815
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_BNH_generation_1510_X
#
#
#
# ============================================================
# problem is:
#  # name: BNH
# # n_var: 2
# # n_obj: 2
# # n_constr: 2
#
# Time elapsed for solving problem:  11.827510833740234  seconds
#
# Generation times 1560
# GD 0.40129467006160785
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_BNH_generation_1560_X
#
#
#
# ============================================================
# problem is:
#  # name: BNH
# # n_var: 2
# # n_obj: 2
# # n_constr: 2
#
# Time elapsed for solving problem:  12.207863092422485  seconds
#
# Generation times 1610
# GD 0.40177247963166207
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_BNH_generation_1610_X
#
#
#
# ============================================================
# problem is:
#  # name: BNH
# # n_var: 2
# # n_obj: 2
# # n_constr: 2
#
# Time elapsed for solving problem:  12.115493774414062  seconds
#
# Generation times 1660
# GD 0.40842925670331776
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_BNH_generation_1660_X
#
#
#
# ============================================================
# problem is:
#  # name: BNH
# # n_var: 2
# # n_obj: 2
# # n_constr: 2
#
# Time elapsed for solving problem:  13.147861957550049  seconds
#
# Generation times 1710
# GD 0.40037553369800116
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_BNH_generation_1710_X
#
#
#
# ============================================================
# problem is:
#  # name: BNH
# # n_var: 2
# # n_obj: 2
# # n_constr: 2
#
# Time elapsed for solving problem:  12.581201076507568  seconds
#
# Generation times 1760
# GD 0.3977835755057153
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_BNH_generation_1760_X
#
#
#
# ============================================================
# problem is:
#  # name: BNH
# # n_var: 2
# # n_obj: 2
# # n_constr: 2
#
# Time elapsed for solving problem:  13.43228006362915  seconds
#
# Generation times 1810
# GD 0.37535981162423154
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_BNH_generation_1810_X
#
#
#
# ============================================================
# problem is:
#  # name: BNH
# # n_var: 2
# # n_obj: 2
# # n_constr: 2
#
# Time elapsed for solving problem:  13.794941186904907  seconds
#
# Generation times 1860
# GD 0.4106158302127904
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_BNH_generation_1860_X
#
#
#
# ============================================================
# problem is:
#  # name: BNH
# # n_var: 2
# # n_obj: 2
# # n_constr: 2
#
# Time elapsed for solving problem:  14.144015073776245  seconds
#
# Generation times 1910
# GD 0.359128236368668
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_BNH_generation_1910_X
#
#
#
# ============================================================
# problem is:
#  # name: BNH
# # n_var: 2
# # n_obj: 2
# # n_constr: 2
#
# Time elapsed for solving problem:  15.07488203048706  seconds
#
# Generation times 1960
# GD 0.41205635502181776
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_BNH_generation_1960_X
# {'1910': 0.359128236368668, '860': 0.3701171386528419, '410': 0.3726711216638205, '1810': 0.37535981162423154, '560': 0.37847102470921856, '1260': 0.37896168845645123, '1060': 0.37984151427308077, '760': 0.3800411202610773, '660': 0.3868173446576783, '1310': 0.3884971327921464, '1410': 0.39329673742775184, '460': 0.39475980562148194, '1460': 0.3957505480642904, '1760': 0.3977835755057153, '1710': 0.40037553369800116, '1560': 0.40129467006160785, '1610': 0.40177247963166207, '210': 0.40301651242607717, '1510': 0.40443826228510815, '10': 0.4066756614383871, '1360': 0.40671948828489085, '1660': 0.40842925670331776, '810': 0.4102968495236827, '1860': 0.4106158302127904, '310': 0.4112158665096189, '1960': 0.41205635502181776, '60': 0.412575447281097, '610': 0.41348535760583344, '260': 0.41485729812380034, '710': 0.41488375031012936, '1010': 0.41695552560002036, '510': 0.41705433056335706, '1210': 0.4193624469441241, '160': 0.42011101494553066, '910': 0.42038180091975036, '110': 0.4319931210896911, '1110': 0.4339890735296518, '360': 0.4370449143983148, '1160': 0.4436967580341547, '960': 0.4459692629245602}
#
#
#
# ============================================================
# problem is:
#  # name: OSY
# # n_var: 6
# # n_obj: 2
# # n_constr: 6
#
# Time elapsed for solving problem:  0.3167259693145752  seconds
#
# Generation times 10
# GD 18.175983320617977
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_OSY_generation_10_X
#
#
#
# ============================================================
# problem is:
#  # name: OSY
# # n_var: 6
# # n_obj: 2
# # n_constr: 6
#
# Time elapsed for solving problem:  0.3869638442993164  seconds
#
# Generation times 60
# GD 2.9481254543436957
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_OSY_generation_60_X
#
#
#
# ============================================================
# problem is:
#  # name: OSY
# # n_var: 6
# # n_obj: 2
# # n_constr: 6
#
# Time elapsed for solving problem:  0.7032911777496338  seconds
#
# Generation times 110
# GD 2.3635484137650122
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_OSY_generation_110_X
#
#
#
# ============================================================
# problem is:
#  # name: OSY
# # n_var: 6
# # n_obj: 2
# # n_constr: 6
#
# Time elapsed for solving problem:  1.3172240257263184  seconds
#
# Generation times 160
# GD 2.391309361969891
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_OSY_generation_160_X
#
#
#
# ============================================================
# problem is:
#  # name: OSY
# # n_var: 6
# # n_obj: 2
# # n_constr: 6
#
# Time elapsed for solving problem:  1.3414678573608398  seconds
#
# Generation times 210
# GD 2.38855774914856
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_OSY_generation_210_X
#
#
#
# ============================================================
# problem is:
#  # name: OSY
# # n_var: 6
# # n_obj: 2
# # n_constr: 6
#
# Time elapsed for solving problem:  1.9907710552215576  seconds
#
# Generation times 260
# GD 2.307798626314356
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_OSY_generation_260_X
#
#
#
# ============================================================
# problem is:
#  # name: OSY
# # n_var: 6
# # n_obj: 2
# # n_constr: 6
#
# Time elapsed for solving problem:  1.9821412563323975  seconds
#
# Generation times 310
# GD 2.433502956232262
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_OSY_generation_310_X
#
#
#
# ============================================================
# problem is:
#  # name: OSY
# # n_var: 6
# # n_obj: 2
# # n_constr: 6
#
# Time elapsed for solving problem:  2.638592004776001  seconds
#
# Generation times 360
# GD 2.3259744442015413
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_OSY_generation_360_X
#
#
#
# ============================================================
# problem is:
#  # name: OSY
# # n_var: 6
# # n_obj: 2
# # n_constr: 6
#
# Time elapsed for solving problem:  2.6216628551483154  seconds
#
# Generation times 410
# GD 2.4644823411187033
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_OSY_generation_410_X
#
#
#
# ============================================================
# problem is:
#  # name: OSY
# # n_var: 6
# # n_obj: 2
# # n_constr: 6
#
# Time elapsed for solving problem:  3.2702980041503906  seconds
#
# Generation times 460
# GD 2.310572989230697
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_OSY_generation_460_X
#
#
#
# ============================================================
# problem is:
#  # name: OSY
# # n_var: 6
# # n_obj: 2
# # n_constr: 6
#
# Time elapsed for solving problem:  3.7584388256073  seconds
#
# Generation times 510
# GD 2.4654701169948234
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_OSY_generation_510_X
#
#
#
# ============================================================
# problem is:
#  # name: OSY
# # n_var: 6
# # n_obj: 2
# # n_constr: 6
#
# Time elapsed for solving problem:  3.9809329509735107  seconds
#
# Generation times 560
# GD 2.613288717255255
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_OSY_generation_560_X
#
#
#
# ============================================================
# problem is:
#  # name: OSY
# # n_var: 6
# # n_obj: 2
# # n_constr: 6
#
# Time elapsed for solving problem:  4.2974231243133545  seconds
#
# Generation times 610
# GD 2.754666083465367
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_OSY_generation_610_X
#
#
#
# ============================================================
# problem is:
#  # name: OSY
# # n_var: 6
# # n_obj: 2
# # n_constr: 6
#
# Time elapsed for solving problem:  4.635848045349121  seconds
#
# Generation times 660
# GD 2.728899963347995
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_OSY_generation_660_X
#
#
#
# ============================================================
# problem is:
#  # name: OSY
# # n_var: 6
# # n_obj: 2
# # n_constr: 6
#
# Time elapsed for solving problem:  4.994642019271851  seconds
#
# Generation times 710
# GD 2.34524107027398
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_OSY_generation_710_X
#
#
#
# ============================================================
# problem is:
#  # name: OSY
# # n_var: 6
# # n_obj: 2
# # n_constr: 6
#
# Time elapsed for solving problem:  5.51996111869812  seconds
#
# Generation times 760
# GD 2.3312505571139712
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_OSY_generation_760_X
#
#
#
# ============================================================
# problem is:
#  # name: OSY
# # n_var: 6
# # n_obj: 2
# # n_constr: 6
#
# Time elapsed for solving problem:  5.843395709991455  seconds
#
# Generation times 810
# GD 2.3942507928304555
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_OSY_generation_810_X
#
#
#
# ============================================================
# problem is:
#  # name: OSY
# # n_var: 6
# # n_obj: 2
# # n_constr: 6
#
# Time elapsed for solving problem:  6.570441007614136  seconds
#
# Generation times 860
# GD 2.674800071878641
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_OSY_generation_860_X
#
#
#
# ============================================================
# problem is:
#  # name: OSY
# # n_var: 6
# # n_obj: 2
# # n_constr: 6
#
# Time elapsed for solving problem:  6.380721092224121  seconds
#
# Generation times 910
# GD 2.592816674096606
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_OSY_generation_910_X
#
#
#
# ============================================================
# problem is:
#  # name: OSY
# # n_var: 6
# # n_obj: 2
# # n_constr: 6
#
# Time elapsed for solving problem:  6.865307807922363  seconds
#
# Generation times 960
# GD 2.7196271692558485
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_OSY_generation_960_X
#
#
#
# ============================================================
# problem is:
#  # name: OSY
# # n_var: 6
# # n_obj: 2
# # n_constr: 6
#
# Time elapsed for solving problem:  7.405133962631226  seconds
#
# Generation times 1010
# GD 2.836264701361844
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_OSY_generation_1010_X
#
#
#
# ============================================================
# problem is:
#  # name: OSY
# # n_var: 6
# # n_obj: 2
# # n_constr: 6
#
# Time elapsed for solving problem:  7.640482664108276  seconds
#
# Generation times 1060
# GD 2.7483563539708826
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_OSY_generation_1060_X
#
#
#
# ============================================================
# problem is:
#  # name: OSY
# # n_var: 6
# # n_obj: 2
# # n_constr: 6
#
# Time elapsed for solving problem:  7.645426273345947  seconds
#
# Generation times 1110
# GD 2.7162636115323466
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_OSY_generation_1110_X
#
#
#
# ============================================================
# problem is:
#  # name: OSY
# # n_var: 6
# # n_obj: 2
# # n_constr: 6
#
# Time elapsed for solving problem:  8.410000324249268  seconds
#
# Generation times 1160
# GD 2.517934528538609
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_OSY_generation_1160_X
#
#
#
# ============================================================
# problem is:
#  # name: OSY
# # n_var: 6
# # n_obj: 2
# # n_constr: 6
#
# Time elapsed for solving problem:  8.247571229934692  seconds
#
# Generation times 1210
# GD 2.757176588509222
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_OSY_generation_1210_X
#
#
#
# ============================================================
# problem is:
#  # name: OSY
# # n_var: 6
# # n_obj: 2
# # n_constr: 6
#
# Time elapsed for solving problem:  8.540617942810059  seconds
#
# Generation times 1260
# GD 2.5044734487559985
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_OSY_generation_1260_X
#
#
#
# ============================================================
# problem is:
#  # name: OSY
# # n_var: 6
# # n_obj: 2
# # n_constr: 6
#
# Time elapsed for solving problem:  9.84634280204773  seconds
#
# Generation times 1310
# GD 2.5404142268016927
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_OSY_generation_1310_X
#
#
#
# ============================================================
# problem is:
#  # name: OSY
# # n_var: 6
# # n_obj: 2
# # n_constr: 6
#
# Time elapsed for solving problem:  9.342096090316772  seconds
#
# Generation times 1360
# GD 2.7420921419817392
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_OSY_generation_1360_X
#
#
#
# ============================================================
# problem is:
#  # name: OSY
# # n_var: 6
# # n_obj: 2
# # n_constr: 6
#
# Time elapsed for solving problem:  10.328409671783447  seconds
#
# Generation times 1410
# GD 2.773702428567998
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_OSY_generation_1410_X
#
#
#
# ============================================================
# problem is:
#  # name: OSY
# # n_var: 6
# # n_obj: 2
# # n_constr: 6
#
# Time elapsed for solving problem:  10.804960012435913  seconds
#
# Generation times 1460
# GD 2.8425856964431153
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_OSY_generation_1460_X
#
#
#
# ============================================================
# problem is:
#  # name: OSY
# # n_var: 6
# # n_obj: 2
# # n_constr: 6
#
# Time elapsed for solving problem:  10.585721731185913  seconds
#
# Generation times 1510
# GD 2.8225686502134066
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_OSY_generation_1510_X
#
#
#
# ============================================================
# problem is:
#  # name: OSY
# # n_var: 6
# # n_obj: 2
# # n_constr: 6
#
# Time elapsed for solving problem:  11.246068000793457  seconds
#
# Generation times 1560
# GD 2.853825129319623
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_OSY_generation_1560_X
#
#
#
# ============================================================
# problem is:
#  # name: OSY
# # n_var: 6
# # n_obj: 2
# # n_constr: 6
#
# Time elapsed for solving problem:  12.249976873397827  seconds
#
# Generation times 1610
# GD 2.8337387226576385
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_OSY_generation_1610_X
#
#
#
# ============================================================
# problem is:
#  # name: OSY
# # n_var: 6
# # n_obj: 2
# # n_constr: 6
#
# Time elapsed for solving problem:  11.626576900482178  seconds
#
# Generation times 1660
# GD 2.876969769607171
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_OSY_generation_1660_X
#
#
#
# ============================================================
# problem is:
#  # name: OSY
# # n_var: 6
# # n_obj: 2
# # n_constr: 6
#
# Time elapsed for solving problem:  12.204031944274902  seconds
#
# Generation times 1710
# GD 2.8373388858874624
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_OSY_generation_1710_X
#
#
#
# ============================================================
# problem is:
#  # name: OSY
# # n_var: 6
# # n_obj: 2
# # n_constr: 6
#
# Time elapsed for solving problem:  11.81049132347107  seconds
#
# Generation times 1760
# GD 2.779752059935317
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_OSY_generation_1760_X
#
#
#
# ============================================================
# problem is:
#  # name: OSY
# # n_var: 6
# # n_obj: 2
# # n_constr: 6
#
# Time elapsed for solving problem:  12.81199312210083  seconds
#
# Generation times 1810
# GD 2.939127012342703
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_OSY_generation_1810_X
#
#
#
# ============================================================
# problem is:
#  # name: OSY
# # n_var: 6
# # n_obj: 2
# # n_constr: 6
#
# Time elapsed for solving problem:  13.032694101333618  seconds
#
# Generation times 1860
# GD 2.8145354947233723
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_OSY_generation_1860_X
#
#
#
# ============================================================
# problem is:
#  # name: OSY
# # n_var: 6
# # n_obj: 2
# # n_constr: 6
#
# Time elapsed for solving problem:  13.315936088562012  seconds
#
# Generation times 1910
# GD 2.7986385212774456
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_OSY_generation_1910_X
#
#
#
# ============================================================
# problem is:
#  # name: OSY
# # n_var: 6
# # n_obj: 2
# # n_constr: 6
#
# Time elapsed for solving problem:  13.666114091873169  seconds
#
# Generation times 1960
# GD 2.763889474768875
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_OSY_generation_1960_X
# {'260': 2.307798626314356, '460': 2.310572989230697, '360': 2.3259744442015413, '760': 2.3312505571139712, '710': 2.34524107027398, '110': 2.3635484137650122, '210': 2.38855774914856, '160': 2.391309361969891, '810': 2.3942507928304555, '310': 2.433502956232262, '410': 2.4644823411187033, '510': 2.4654701169948234, '1260': 2.5044734487559985, '1160': 2.517934528538609, '1310': 2.5404142268016927, '910': 2.592816674096606, '560': 2.613288717255255, '860': 2.674800071878641, '1110': 2.7162636115323466, '960': 2.7196271692558485, '660': 2.728899963347995, '1360': 2.7420921419817392, '1060': 2.7483563539708826, '610': 2.754666083465367, '1210': 2.757176588509222, '1960': 2.763889474768875, '1410': 2.773702428567998, '1760': 2.779752059935317, '1910': 2.7986385212774456, '1860': 2.8145354947233723, '1510': 2.8225686502134066, '1610': 2.8337387226576385, '1010': 2.836264701361844, '1710': 2.8373388858874624, '1460': 2.8425856964431153, '1560': 2.853825129319623, '1660': 2.876969769607171, '1810': 2.939127012342703, '60': 2.9481254543436957, '10': 18.175983320617977}
#
#
#
# ============================================================
# problem is:
#  # name: TNK
# # n_var: 2
# # n_obj: 2
# # n_constr: 2
#
# Time elapsed for solving problem:  0.26281023025512695  seconds
#
# Generation times 10
# GD 0.020831072333003443
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_TNK_generation_10_X
#
#
#
# ============================================================
# problem is:
#  # name: TNK
# # n_var: 2
# # n_obj: 2
# # n_constr: 2
#
# Time elapsed for solving problem:  0.379274845123291  seconds
#
# Generation times 60
# GD 0.005747279611720869
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_TNK_generation_60_X
#
#
#
# ============================================================
# problem is:
#  # name: TNK
# # n_var: 2
# # n_obj: 2
# # n_constr: 2
#
# Time elapsed for solving problem:  0.6905078887939453  seconds
#
# Generation times 110
# GD 0.004612092954180078
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_TNK_generation_110_X
#
#
#
# ============================================================
# problem is:
#  # name: TNK
# # n_var: 2
# # n_obj: 2
# # n_constr: 2
#
# Time elapsed for solving problem:  1.0178420543670654  seconds
#
# Generation times 160
# GD 0.004613050905374134
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_TNK_generation_160_X
#
#
#
# ============================================================
# problem is:
#  # name: TNK
# # n_var: 2
# # n_obj: 2
# # n_constr: 2
#
# Time elapsed for solving problem:  1.3444938659667969  seconds
#
# Generation times 210
# GD 0.0038485631032816876
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_TNK_generation_210_X
#
#
#
# ============================================================
# problem is:
#  # name: TNK
# # n_var: 2
# # n_obj: 2
# # n_constr: 2
#
# Time elapsed for solving problem:  1.6732568740844727  seconds
#
# Generation times 260
# GD 0.0035915271806424105
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_TNK_generation_260_X
#
#
#
# ============================================================
# problem is:
#  # name: TNK
# # n_var: 2
# # n_obj: 2
# # n_constr: 2
#
# Time elapsed for solving problem:  2.331845998764038  seconds
#
# Generation times 310
# GD 0.0035244769711565887
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_TNK_generation_310_X
#
#
#
# ============================================================
# problem is:
#  # name: TNK
# # n_var: 2
# # n_obj: 2
# # n_constr: 2
#
# Time elapsed for solving problem:  2.6705732345581055  seconds
#
# Generation times 360
# GD 0.0038246648331154765
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_TNK_generation_360_X
#
#
#
# ============================================================
# problem is:
#  # name: TNK
# # n_var: 2
# # n_obj: 2
# # n_constr: 2
#
# Time elapsed for solving problem:  2.674269199371338  seconds
#
# Generation times 410
# GD 0.003576261834557776
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_TNK_generation_410_X
#
#
#
# ============================================================
# problem is:
#  # name: TNK
# # n_var: 2
# # n_obj: 2
# # n_constr: 2
#
# Time elapsed for solving problem:  3.283949851989746  seconds
#
# Generation times 460
# GD 0.0046235326054198085
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_TNK_generation_460_X
#
#
#
# ============================================================
# problem is:
#  # name: TNK
# # n_var: 2
# # n_obj: 2
# # n_constr: 2
#
# Time elapsed for solving problem:  3.7382020950317383  seconds
#
# Generation times 510
# GD 0.004625380897213971
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_TNK_generation_510_X
#
#
#
# ============================================================
# problem is:
#  # name: TNK
# # n_var: 2
# # n_obj: 2
# # n_constr: 2
#
# ...
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_Welded_Beam_generation_1110_X
#
#
#
# ============================================================
# problem is:
#  # name: WeldedBeam
# # n_var: 4
# # n_obj: 2
# # n_constr: 4
#
# Time elapsed for solving problem:  7.968448877334595  seconds
#
# Generation times 1160
# GD 0.034584156299255236
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_Welded_Beam_generation_1160_X
#
#
#
# ============================================================
# problem is:
#  # name: WeldedBeam
# # n_var: 4
# # n_obj: 2
# # n_constr: 4
#
# Time elapsed for solving problem:  8.717587947845459  seconds
#
# Generation times 1210
# GD 0.03673349632370564
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_Welded_Beam_generation_1210_X
#
#
#
# ============================================================
# problem is:
#  # name: WeldedBeam
# # n_var: 4
# # n_obj: 2
# # n_constr: 4
#
# Time elapsed for solving problem:  8.594573020935059  seconds
#
# Generation times 1260
# GD 0.03583210216928125
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_Welded_Beam_generation_1260_X
#
#
#
# ============================================================
# problem is:
#  # name: WeldedBeam
# # n_var: 4
# # n_obj: 2
# # n_constr: 4
#
# Time elapsed for solving problem:  9.511360883712769  seconds
#
# Generation times 1310
# GD 0.03473251553489352
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_Welded_Beam_generation_1310_X
#
#
#
# ============================================================
# problem is:
#  # name: WeldedBeam
# # n_var: 4
# # n_obj: 2
# # n_constr: 4
#
# Time elapsed for solving problem:  9.331268787384033  seconds
#
# Generation times 1360
# GD 0.04002384370826203
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_Welded_Beam_generation_1360_X
#
#
#
# ============================================================
# problem is:
#  # name: WeldedBeam
# # n_var: 4
# # n_obj: 2
# # n_constr: 4
#
# Time elapsed for solving problem:  10.15031099319458  seconds
#
# Generation times 1410
# GD 0.03448639744109434
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_Welded_Beam_generation_1410_X
#
#
#
# ============================================================
# problem is:
#  # name: WeldedBeam
# # n_var: 4
# # n_obj: 2
# # n_constr: 4
#
# Time elapsed for solving problem:  10.615649223327637  seconds
#
# Generation times 1460
# GD 0.033674461458284476
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_Welded_Beam_generation_1460_X
#
#
#
# ============================================================
# problem is:
#  # name: WeldedBeam
# # n_var: 4
# # n_obj: 2
# # n_constr: 4
#
# Time elapsed for solving problem:  10.888507843017578  seconds
#
# Generation times 1510
# GD 0.04049273464113197
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_Welded_Beam_generation_1510_X
#
#
#
# ============================================================
# problem is:
#  # name: WeldedBeam
# # n_var: 4
# # n_obj: 2
# # n_constr: 4
#
# Time elapsed for solving problem:  10.735481977462769  seconds
#
# Generation times 1560
# GD 0.0371764907544925
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_Welded_Beam_generation_1560_X
#
#
#
# ============================================================
# problem is:
#  # name: WeldedBeam
# # n_var: 4
# # n_obj: 2
# # n_constr: 4
#
# Time elapsed for solving problem:  11.57520318031311  seconds
#
# Generation times 1610
# GD 0.038336652453957815
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_Welded_Beam_generation_1610_X
#
#
#
# ============================================================
# problem is:
#  # name: WeldedBeam
# # n_var: 4
# # n_obj: 2
# # n_constr: 4
#
# Time elapsed for solving problem:  11.988358974456787  seconds
#
# Generation times 1660
# GD 0.03724407191654407
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_Welded_Beam_generation_1660_X
#
#
#
# ============================================================
# problem is:
#  # name: WeldedBeam
# # n_var: 4
# # n_obj: 2
# # n_constr: 4
#
# Time elapsed for solving problem:  11.689144849777222  seconds
#
# Generation times 1710
# GD 0.03772606398964676
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_Welded_Beam_generation_1710_X
#
#
#
# ============================================================
# problem is:
#  # name: WeldedBeam
# # n_var: 4
# # n_obj: 2
# # n_constr: 4
#
# Time elapsed for solving problem:  12.59655213356018  seconds
#
# Generation times 1760
# GD 0.03422250875845665
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_Welded_Beam_generation_1760_X
#
#
#
# ============================================================
# problem is:
#  # name: WeldedBeam
# # n_var: 4
# # n_obj: 2
# # n_constr: 4
#
# Time elapsed for solving problem:  13.178101062774658  seconds
#
# Generation times 1810
# GD 0.03637421988150162
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_Welded_Beam_generation_1810_X
#
#
#
# ============================================================
# problem is:
#  # name: WeldedBeam
# # n_var: 4
# # n_obj: 2
# # n_constr: 4
#
# Time elapsed for solving problem:  12.681553840637207  seconds
#
# Generation times 1860
# GD 0.03502362790045641
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_Welded_Beam_generation_1860_X
#
#
#
# ============================================================
# problem is:
#  # name: WeldedBeam
# # n_var: 4
# # n_obj: 2
# # n_constr: 4
#
# Time elapsed for solving problem:  13.660938024520874  seconds
#
# Generation times 1910
# GD 0.03323596565085099
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_Welded_Beam_generation_1910_X
#
#
#
# ============================================================
# problem is:
#  # name: WeldedBeam
# # n_var: 4
# # n_obj: 2
# # n_constr: 4
#
# Time elapsed for solving problem:  14.268511772155762  seconds
#
# Generation times 1960
# GD 0.033847784285441274
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II/NSGA-II_Welded_Beam_generation_1960_X
# {'760': 0.03223948946196988, '1910': 0.03323596565085099, '560': 0.03349887351786558, '1460': 0.033674461458284476, '1960': 0.033847784285441274, '960': 0.03411108791500954, '1760': 0.03422250875845665, '1410': 0.03448639744109434, '1160': 0.034584156299255236, '1310': 0.03473251553489352, '1860': 0.03502362790045641, '460': 0.035202704086011685, '1260': 0.03583210216928125, '1810': 0.03637421988150162, '910': 0.0364854966965386, '510': 0.036574663676355104, '1210': 0.03673349632370564, '860': 0.036887633357258164, '1010': 0.03717323359049438, '1560': 0.0371764907544925, '810': 0.03723925144985479, '1660': 0.03724407191654407, '1110': 0.037506973859472104, '1710': 0.03772606398964676, '710': 0.03804580283050393, '1060': 0.038317979670185076, '1610': 0.038336652453957815, '610': 0.038824830668262464, '260': 0.03953781885546349, '660': 0.03966711114702573, '1360': 0.04002384370826203, '410': 0.04037281859539877, '1510': 0.04049273464113197, '210': 0.04059985679596165, '360': 0.04219766338033093, '160': 0.057784876035712605, '110': 0.07446999095959271, '310': 0.1016867833852357, '60': 0.16241158987793042, '10': 0.7925541052966683}
#    print(path)

#!select problems here 
problem_list = ['BNH', 'OSY', 'TNK', 'Truss2D', 'Welded_Beam', 'zdt1','ZDT2','ZDT3','ZDT4','ZDT5','ZDT6']
select_problem_list = ['BNH', 'OSY', 'TNK','Truss2D','Welded_Beam']


problem_dict = {}

#! set pop_size list here
pop_list = list(range(10,1500,10)) ####!!!!!!!!!!!


for problem_name in select_problem_list:
    pop_dict = {}
    for pop_name in pop_list:
        print('\n\n')
        print('-'*60)
        print('-'*60)

        p = get_problem(problem_name)
        print('problem is:\n',p)
        
        #default setting for termination
        termination = MultiObjectiveDefaultTermination(

        n_max_gen=1500,
        n_max_evals=1500
        )
        #algorithm parameters
        algorithm = NSGA2(
        pop_size= pop_name, #! parameters
        n_offspring = 20,
    #    crossover=get_crossover("real_sbx", prob=0.9, eta=15),
    #    mutation=get_mutation("real_pm", eta=20),
        eliminate_duplicates=True,
        termination = termination 
    )

        start = time.time()
        res = minimize(p,
                algorithm,
                termination,
                seed=1,
                save_history=True,
                verbose=False)

        print('Time elapsed for solving problem: ', time.time() - start, ' seconds\n')
        
        print('population size',pop_name)
        print("Best solution found: {}".format(res.X.shape)) #pareto solution set 
        print("Function value: {}".format(res.F.shape)) #object function value 
    # print("Constraint violation: {}".format(res.CV.shape)) 
        #join directory 
        
        pf = p.pareto_front()
        gd = get_performance_indicator("gd",pf ) 
        if pf is not None:
            pop_dict[str(pop_name)] = gd.calc(res.F)
            print("GD", gd.calc(res.F))
        
        path = os.path.join(os.getcwd(), 'Result','Algorithmn_Result', 'NAGA-II' )

        print(path)
        try:
            os.makedirs(path)
        except OSError:
            print ("Creation of the directory %s failed" % path)
        else:
            print ("Successfully created the directory %s" % path)


        best_solution_path = path + '/NSGA-II_' + str(problem_name)+'_popsize_' + str(pop_name) + '_X'
        objective_value_path= path + '/NSGA-II_' + str(problem_name) + '_popsize_' +str(pop_name) + '_F'
        

        with open(best_solution_path, 'w+') as f:  # infeasible point, outside feasible domain
            print(res.X, sep=' ', file=f)

        with open(objective_value_path, 'w+') as f:  # infeasible point, outside feasible domain
            print(res.F, sep=' ', file=f)

    sorted_dict = dict(sorted(pop_dict.items(),
                        key=lambda item: item[1],
                        reverse=False))      

    problem_dict[problem_name] = sorted_dict

print('-'*60)

for i in problem_dict.keys():
    print(i,problem_dict[i])
    print('\n')
# Out:
# 287497972154, '1410': 0.39592718100099883, '320': 0.39633698595838074, '250': 0.39728008579819696, '80': 0.397386198059657, '1470': 0.3979340997476716, '360': 0.398241913299925, '1460': 0.3985105978430082, '390': 0.3990339763501785, '1330': 0.4000006784964755, '1490': 0.40037227281125065, '1400': 0.4010266994350227, '1380': 0.4021852109209538, '260': 0.40446471935254186, '1220': 0.404467423085297, '680': 0.40474870278726083, '1450': 0.40475545676454555, '350': 0.40573185698570874, '1270': 0.40635692390944533, '1350': 0.40648456190455157, '160': 0.40683163120162896, '290': 0.40724257379293527, '200': 0.4073555329482444, '1310': 0.40762294869875915, '20': 0.40831189427142434, '1290': 0.4098845395927688, '1390': 0.4
3550268930317309, '460': 1.4204918861626685, '960': 1.4739586843421433, '1020': 1.6906972774895173, '490': 1.7509170124382492, '550': 1.7934924427669408, '890': 1.8026345831867316, '1170': 1.8168713498360514, '1180': 1.8879970278213007, '1110': 1.896574878155226, '240': 1.9008870567467362, '850': 1.9601421068992342, '1010': 2.005191918098696, '1050': 2.06251603819193, '1350': 2.0824386328078828, '160': 2.347449301492817, '700': 2.361263710145387, '1130': 2.4111710739968646, '560': 2.561847656968587, '770': 2.5743988505759394, '1080': 2.5754931492402053, '400': 2.6319486071890603, '410': 2.6874262741574393, '430': 2.700921749875871, '980': 2.767273772478083, '1410': 2.76922512975837, '570': 2.7954288466082327, '680': 2.8370009168701262, '1490': 2.8805778461659823, '1300': 2.9293322585806836, '1460': 3.0266904506257637, '1120': 3.0497449512200023, '280': 3.1120507634502936, '420': 3.1732148128089976, '1150': 3.204769765018208, '500': 3.368608986042152, '1430': 3.3949133639102573, '1450': 3.425229941651442, '1230': 3.430721786694011, '820': 3.474756987289219, '1380': 3.4758533004664773, '970': 3.6007845588312493, '720': 3.6540730830327828, '810': 3.697664108096915, '340': 3.802541924249269, '910': 3.8472314942801678, '1260': 3.940116249058015, '1420': 3.9483530923581758, '950': 3.9866998535839966, '1470': 4.065849818555971, '1390': 4.1686448044579905, '1370': 4.209244337253167, '1280': 4.227063687598571, '260': 4.4821827364581335, '1360': 4.573423848146712, '1310': 4.6292677543098355, '1100': 4.66981811714457, '150': 4.741103965768554, '350': 4.8264485506978065, '620': 4.835350101983561, '920': 4.913347163300685, '880': 4.954791852203268, '860': 5.063788740598433, '840': 5.1819125854672246, '930': 5.245156352909357, '1160': 5.285818699125558, '440': 5.452732421250163, '1340': 5.758378686812137, '1140': 5.955256209218593, '360': 6.323686946933325, '940': 6.613269830223396, '740': 6.737330451774036, '540': 6.8770827444655325, '1040': 6.938718308509268, '1060': 7.080723613243339, '510': 7.1254867884676285, '310': 7.1643596310449125, '730': 7.176383628169741, '900': 7.421245488822526, '990': 7.919269136797791, '1210': 8.276366123069536, '760': 8.77830937145152, '1480': 8.784411655753667, '1320': 8.953958927764226, '480': 9.32124693682402, '530': 9.363230204027321, '1090': 9.65285300396841, '1290': 9.703825208492015, '710': 9.93952413802567, '1240': 10.374232524961148, '470': 10.764342629639117, '1270': 11.566251929601584, '390': 11.953994265857835, '1330': 12.611806577455754, '650': 12.665824299003775, '1190': 13.565867636187768, '380': 15.071511894266363,  ...

# %% [markdown]
# ## N_Evals

# %%
from pymoo.algorithms.nsga2 import NSGA2
from pymoo.factory import get_sampling, get_crossover, get_mutation, get_termination
from pymoo.factory import get_problem
from pymoo.optimize import minimize
from pymoo.visualization.scatter import Scatter
from pymoo.util.termination.default import MultiObjectiveDefaultTermination
from pymoo.factory import get_performance_indicator
import numpy as np
import time
import sys
import os 

#for path in sys.path:
#    print(path)

problem_list = ['BNH', 'OSY', 'TNK', 'Truss2D', 'Welded_Beam', 'zdt1','ZDT2','ZDT3','ZDT4','ZDT5','ZDT6']

select_problem_list = ['BNH', 'OSY', 'TNK','Truss2D','Welded_Beam']

problem_dict = {}



#! set pop_size list here
####!!!!!!!!!!!
n_evals_list = list(range(10,3000,50))


for problem_name in select_problem_list:
    GD_list = {}

    for n_evals in n_evals_list:  
        print('\n\n')
        print('-'*60)
        print('-'*60)

        p = get_problem(problem_name)
        print('problem is:\n',p)
        pf = p.pareto_front()
        gd = get_performance_indicator("gd",pf )

        #algorithm parameters
        algorithm = NSGA2(
        n_offspring = 20,
        crossover=get_crossover("real_sbx", prob=0.9, eta=15),
        mutation=get_mutation("real_pm", eta=20),
        eliminate_duplicates=True
        
    )
        termination = get_termination("n_eval", n_evals)
        start = time.time()
        res = minimize(p,
                algorithm,
                termination = termination,
                seed=1,
                save_history=True,
                verbose=False)
                
        print('Time elapsed for solving problem: ', time.time() - start, ' seconds\n')
        problem_dict[problem_name] = {'Solution':np.array(res.X), 'Obj_value':np.array(res.F), 'CV':np.array(res.CV)}

        print('Evaluation times:', n_evals)
        print("Best solution found: {}".format(res.X.shape)) #pareto solution set 
        if pf is not None:
            GD_list[str(n_evals)] = gd.calc(res.F)
            print("GD", gd.calc(res.F))

        print("Function value: {}".format(res.F.shape)) #object function value 
        print("Constraint violation: {}".format(res.CV.shape)) 
        #join directory 
        
        path = os.path.join(os.getcwd(), 'Result','Algorithmn_Result', 'NAGA-II' )

        print(path)
        try:
            os.makedirs(path)
        except OSError:
            print ("Creation of the directory %s failed" % path)
        else:
            print ("Successfully created the directory %s" % path)


        best_solution_path = path + '/NSGA-II_' + str(problem_name)+'_evals_' + str(n_evals) + '_X'
        objective_value_path= path + '/NSGA-II_' + str(problem_name) + '_evals_' +str(n_evals) + '_F'
        

        with open(best_solution_path, 'w+') as f:  # infeasible point, outside feasible domain
            print(res.X, sep=' ', file=f)

        with open(objective_value_path, 'w+') as f:  # infeasible point, outside feasible domain
            print(res.F, sep=' ', file=f)
    
    
    
    sorted_dict = dict(sorted(GD_list.items(),
                        key=lambda item: item[1],
                        reverse=False))      


    problem_dict[problem_name] = sorted_dict

print('-'*60)

for i in problem_dict.keys():
    print(i,problem_dict[i])
    print('\n')
# Out:
# ------------------------------------------------------------
# ------------------------------------------------------------
# problem is:
#  # name: BNH
# # n_var: 2
# # n_obj: 2
# # n_constr: 2
#
# Time elapsed for solving problem:  0.007035970687866211  seconds
#
# Evaluation times: 10
# Best solution found: (32, 2)
# GD 0.6853353204814265
# Function value: (32, 2)
# Constraint violation: (32, 1)
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
#
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# problem is:
#  # name: BNH
# # n_var: 2
# # n_obj: 2
# # n_constr: 2
#
# Time elapsed for solving problem:  0.005425214767456055  seconds
#
# Evaluation times: 60
# Best solution found: (32, 2)
# GD 0.6853353204814265
# Function value: (32, 2)
# Constraint violation: (32, 1)
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
#
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# problem is:
#  # name: BNH
# # n_var: 2
# # n_obj: 2
# # n_constr: 2
#
# Time elapsed for solving problem:  0.013242959976196289  seconds
#
# Evaluation times: 110
# Best solution found: (53, 2)
# GD 0.6185397605304154
# Function value: (53, 2)
# Constraint violation: (53, 1)
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
#
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# problem is:
#  # name: BNH
# # n_var: 2
# # n_obj: 2
# # n_constr: 2
#
# Time elapsed for solving problem:  0.012775897979736328  seconds
#
# Evaluation times: 160
# Best solution found: (53, 2)
# GD 0.6185397605304154
# Function value: (53, 2)
# Constraint violation: (53, 1)
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
#
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# problem is:
#  # name: BNH
# # n_var: 2
# # n_obj: 2
# # n_constr: 2
#
# Time elapsed for solving problem:  0.01959395408630371  seconds
#
# Evaluation times: 210
# Best solution found: (82, 2)
# GD 0.566634510627196
# Function value: (82, 2)
# Constraint violation: (82, 1)
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
#
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# problem is:
#  # name: BNH
# # n_var: 2
# # n_obj: 2
# # n_constr: 2
#
# Time elapsed for solving problem:  0.01959514617919922  seconds
#
# Evaluation times: 260
# Best solution found: (82, 2)
# GD 0.566634510627196
# Function value: (82, 2)
# Constraint violation: (82, 1)
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
#
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# problem is:
#  # name: BNH
# # n_var: 2
# # n_obj: 2
# # n_constr: 2
#
# Time elapsed for solving problem:  0.029620885848999023  seconds
#
# Evaluation times: 310
# Best solution found: (100, 2)
# GD 0.5333166168074782
# Function value: (100, 2)
# Constraint violation: (100, 1)
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
#
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# problem is:
#  # name: BNH
# # n_var: 2
# # n_obj: 2
# # n_constr: 2
#
# Time elapsed for solving problem:  0.027547836303710938  seconds
#
# Evaluation times: 360
# Best solution found: (100, 2)
# GD 0.5333166168074782
# Function value: (100, 2)
# Constraint violation: (100, 1)
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
#
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# problem is:
#  # name: BNH
# # n_var: 2
# # n_obj: 2
# # n_constr: 2
#
# Time elapsed for solving problem:  0.03669905662536621  seconds
#
# Evaluation times: 410
# Best solution found: (100, 2)
# GD 0.5175951294780777
# Function value: (100, 2)
# Constraint violation: (100, 1)
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
#
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# problem is:
#  # name: BNH
# # n_var: 2
# # n_obj: 2
# # n_constr: 2
#
# Time elapsed for solving problem:  0.03868389129638672  seconds
#
# Evaluation times: 460
# Best solution found: (100, 2)
# GD 0.5175951294780777
# Function value: (100, 2)
# Constraint violation: (100, 1)
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
#
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# problem is:
#  # name: BNH
# # n_var: 2
# # n_obj: 2
# # n_constr: 2
#
# Time elapsed for solving problem:  0.043385982513427734  seconds
#
# Evaluation times: 510
# Best solution found: (100, 2)
# GD 0.4712777986435834
# Function value: (100, 2)
# Constraint violation: (100, 1)
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
#
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# problem is:
#  # name: BNH
# # n_var: 2
# # n_obj: 2
# # n_constr: 2
#
# Time elapsed for solving problem:  0.0449678897857666  seconds
#
# Evaluation times: 560
# Best solution found: (100, 2)
# GD 0.4712777986435834
# Function value: (100, 2)
# Constraint violation: (100, 1)
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
#
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# problem is:
#  # name: BNH
# # n_var: 2
# # n_obj: 2
# # n_constr: 2
#
# Time elapsed for solving problem:  0.0482480525970459  seconds
#
# Evaluation times: 610
# Best solution found: (100, 2)
# GD 0.46565411425995046
# Function value: (100, 2)
# Constraint violation: (100, 1)
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
#
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# problem is:
#  # name: BNH
# # n_var: 2
# # n_obj: 2
# # n_constr: 2
#
# Time elapsed for solving problem:  0.07043981552124023  seconds
#
# Evaluation times: 660
# Best solution found: (100, 2)
# GD 0.46565411425995046
# Function value: (100, 2)
# Constraint violation: (100, 1)
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
#
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# problem is:
#  # name: BNH
# # n_var: 2
# # n_obj: 2
# # n_constr: 2
#
# Time elapsed for solving problem:  0.05369997024536133  seconds
#
# Evaluation times: 710
# Best solution found: (100, 2)
# GD 0.46872616811211243
# Function value: (100, 2)
# Constraint violation: (100, 1)
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
#
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# problem is:
#  # name: BNH
# # n_var: 2
# # n_obj: 2
# # n_constr: 2
#
# Time elapsed for solving problem:  0.05566906929016113  seconds
#
# Evaluation times: 760
# Best solution found: (100, 2)
# GD 0.46872616811211243
# Function value: (100, 2)
# Constraint violation: (100, 1)
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
#
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# problem is:
#  # name: BNH
# # n_var: 2
# # n_obj: 2
# # n_constr: 2
#
# Time elapsed for solving problem:  0.06547784805297852  seconds
#
# Evaluation times: 810
# Best solution found: (100, 2)
# GD 0.43518503269982056
# Function value: (100, 2)
# Constraint violation: (100, 1)
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
#
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# problem is:
#  # name: BNH
# # n_var: 2
# # n_obj: 2
# # n_constr: 2
#
# Time elapsed for solving problem:  0.06570816040039062  seconds
#
# Evaluation times: 860
# Best solution found: (100, 2)
# GD 0.43518503269982056
# Function value: (100, 2)
# Constraint violation: (100, 1)
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
#
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# problem is:
#  # name: BNH
# # n_var: 2
# # n_obj: 2
# # n_constr: 2
#
# Time elapsed for solving problem:  0.07285571098327637  seconds
#
# Evaluation times: 910
# Best solution found: (100, 2)
# GD 0.4066756614383871
# Function value: (100, 2)
# Constraint violation: (100, 1)
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
#
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# problem is:
#  # name: BNH
# # n_var: 2
# # n_obj: 2
# # n_constr: 2
#
# Time elapsed for solving problem:  0.07012510299682617  seconds
#
# Evaluation times: 960
# Best solution found: (100, 2)
# GD 0.4066756614383871
# Function value: (100, 2)
# Constraint violation: (100, 1)
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
#
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# problem is:
#  # name: BNH
# # n_var: 2
# # n_obj: 2
# # n_constr: 2
#
# Time elapsed for solving problem:  0.07709813117980957  seconds
#
# Evaluation times: 1010
# Best solution found: (100, 2)
# GD 0.40257121167643417
# Function value: (100, 2)
# Constraint violation: (100, 1)
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
#
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# problem is:
#  # name: BNH
# # n_var: 2
# # n_obj: 2
# # n_constr: 2
#
# Time elapsed for solving problem:  0.09930968284606934  seconds
#
# Evaluation times: 1060
# Best solution found: (100, 2)
# GD 0.40257121167643417
# Function value: (100, 2)
# Constraint violation: (100, 1)
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
#
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# problem is:
#  # name: BNH
# # n_var: 2
# # n_obj: 2
# # n_constr: 2
#
# Time elapsed for solving problem:  0.08413386344909668  seconds
#
# Evaluation times: 1110
# Best solution found: (100, 2)
# GD 0.38850645832948205
# Function value: (100, 2)
# Constraint violation: (100, 1)
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
#
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# problem is:
#  # name: BNH
# # n_var: 2
# # n_obj: 2
# # n_constr: 2
#
# Time elapsed for solving problem:  0.08271002769470215  seconds
#
# Evaluation times: 1160
# Best solution found: (100, 2)
# GD 0.38850645832948205
# Function value: (100, 2)
# Constraint violation: (100, 1)
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
#
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# problem is:
#  # name: BNH
# # n_var: 2
# # n_obj: 2
# # n_constr: 2
#
# Time elapsed for solving problem:  0.08877110481262207  seconds
#
# Evaluation times: 1210
# Best solution found: (100, 2)
# GD 0.38473508395789335
# Function value: (100, 2)
# Constraint violation: (100, 1)
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
#
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# problem is:
#  # name: BNH
# # n_var: 2
# # n_obj: 2
# # n_constr: 2
#
# Time elapsed for solving problem:  0.08601117134094238  seconds
#
# Evaluation times: 1260
# Best solution found: (100, 2)
# GD 0.38473508395789335
# Function value: (100, 2)
# Constraint violation: (100, 1)
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
#
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# problem is:
#  # name: BNH
# # n_var: 2
# # n_obj: 2
# # n_constr: 2
#
# Time elapsed for solving problem:  0.10961484909057617  seconds
#
# Evaluation times: 1310
# Best solution found: (100, 2)
# GD 0.3851667151545989
# Function value: (100, 2)
# Constraint violation: (100, 1)
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
#
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# problem is:
#  # name: BNH
# # n_var: 2
# # n_obj: 2
# # n_constr: 2
#
# Time elapsed for solving problem:  0.09359216690063477  seconds
#
# Evaluation times: 1360
# Best solution found: (100, 2)
# GD 0.3851667151545989
# Function value: (100, 2)
# Constraint violation: (100, 1)
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
#
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# problem is:
#  # name: BNH
# # n_var: 2
# # n_obj: 2
# # n_constr: 2
#
# Time elapsed for solving problem:  0.09845232963562012  seconds
#
# Evaluation times: 1410
# Best solution found: (100, 2)
# GD 0.3404297944868695
# Function value: (100, 2)
# Constraint violation: (100, 1)
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
#
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# problem is:
#  # name: BNH
# # n_var: 2
# # n_obj: 2
# # n_constr: 2
#
# Time elapsed for solving problem:  0.0993199348449707  seconds
#
# Evaluation times: 1460
# Best solution found: (100, 2)
# GD 0.3404297944868695
# Function value: (100, 2)
# Constraint violation: (100, 1)
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
#
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# problem is:
#  # name: BNH
# # n_var: 2
# # n_obj: 2
# # n_constr: 2
#
# Time elapsed for solving problem:  0.10669493675231934  seconds
#
# Evaluation times: 1510
# Best solution found: (100, 2)
# GD 0.36420236333221373
# Function value: (100, 2)
# Constraint violation: (100, 1)
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
#
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# problem is:
#  # name: BNH
# # n_var: 2
# # n_obj: 2
# # n_constr: 2
#
# Time elapsed for solving problem:  0.12677621841430664  seconds
#
# Evaluation times: 1560
# Best solution found: (100, 2)
# GD 0.36420236333221373
# Function value: (100, 2)
# Constraint violation: (100, 1)
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
#
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# problem is:
#  # name: BNH
# # n_var: 2
# # n_obj: 2
# # n_constr: 2
#
# Time elapsed for solving problem:  0.12198495864868164  seconds
#
# Evaluation times: 1610
# Best solution found: (100, 2)
# GD 0.36121723435568515
# Function value: (100, 2)
# Constraint violation: (100, 1)
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
#
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# problem is:
#  # name: BNH
# # n_var: 2
# # n_obj: 2
# # n_constr: 2
#
# Time elapsed for solving problem:  0.11503005027770996  seconds
#
# Evaluation times: 1660
# Best solution found: (100, 2)
# GD 0.36121723435568515
# Function value: (100, 2)
# Constraint violation: (100, 1)
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
#
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# problem is:
#  # name: BNH
# # n_var: 2
# # n_obj: 2
# # n_constr: 2
#
# Time elapsed for solving problem:  0.12389206886291504  seconds
#
# Evaluation times: 1710
# Best solution found: (100, 2)
# GD 0.3426728407580243
# Function value: (100, 2)
# Constraint violation: (100, 1)
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
#
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# problem is:
#  # name: BNH
# # n_var: 2
# # n_obj: 2
# # n_constr: 2
#
# Time elapsed for solving problem:  0.14110732078552246  seconds
#
# Evaluation times: 1760
# Best solution found: (100, 2)
# GD 0.3426728407580243
# Function value: (100, 2)
# Constraint violation: (100, 1)
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
#
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# problem is:
#  # name: BNH
# # n_var: 2
# # n_obj: 2
# # n_constr: 2
#
# Time elapsed for solving problem:  0.12979388236999512  seconds
#
# Evaluation times: 1810
# Best solution found: (100, 2)
# GD 0.3606750525576992
# Function value: (100, 2)
# Constraint violation: (100, 1)
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
#
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# problem is:
#  # name: BNH
# # n_var: 2
# # n_obj: 2
# # n_constr: 2
#
# Time elapsed for solving problem:  0.1299269199371338  seconds
#
# Evaluation times: 1860
# Best solution found: (100, 2)
# GD 0.3606750525576992
# Function value: (100, 2)
# Constraint violation: (100, 1)
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
#
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# problem is:
#  # name: BNH
# # n_var: 2
# # n_obj: 2
# # n_constr: 2
#
# Time elapsed for solving problem:  0.15938210487365723  seconds
#
# Evaluation times: 1910
# Best solution found: (100, 2)
# GD 0.37742743354693753
# Function value: (100, 2)
# Constraint violation: (100, 1)
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
#
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# problem is:
#  # name: BNH
# # n_var: 2
# # n_obj: 2
# # n_constr: 2
#
# Time elapsed for solving problem:  0.13599681854248047  seconds
#
# Evaluation times: 1960
# Best solution found: (100, 2)
# GD 0.37742743354693753
# Function value: (100, 2)
# Constraint violation: (100, 1)
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
#
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# problem is:
#  # name: BNH
# # n_var: 2
# # n_obj: 2
# # n_constr: 2
#
# Time elapsed for solving problem:  0.14583396911621094  seconds
#
# Evaluation times: 2010
# Best solution found: (100, 2)
# GD 0.3787495601760043
# Function value: (100, 2)
# Constraint violation: (100, 1)
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
#
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# problem is:
#  # name: BNH
# # n_var: 2
# # n_obj: 2
# # n_constr: 2
#
# Time elapsed for solving problem:  0.14247488975524902  seconds
#
# Evaluation times: 2060
# Best solution found: (100, 2)
# GD 0.3787495601760043
# Function value: (100, 2)
# Constraint violation: (100, 1)
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
#
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# problem is:
#  # name: BNH
# # n_var: 2
# # n_obj: 2
# # n_constr: 2
#
# Time elapsed for solving problem:  0.16769981384277344  seconds
#
# Evaluation times: 2110
# Best solution found: (100, 2)
# GD 0.38157435771048226
# Function value: (100, 2)
# Constraint violation: (100, 1)
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
#
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# problem is:
#  # name: BNH
# # n_var: 2
# # n_obj: 2
# # n_constr: 2
#
# Time elapsed for solving problem:  0.14455199241638184  seconds
#
# Evaluation times: 2160
# Best solution found: (100, 2)
# GD 0.38157435771048226
# Function value: (100, 2)
# Constraint violation: (100, 1)
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
#
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# problem is:
#  # name: BNH
# # n_var: 2
# # n_obj: 2
# # n_constr: 2
#
# Time elapsed for solving problem:  0.15399718284606934  seconds
#
# Evaluation times: 2210
# Best solution found: (100, 2)
# GD 0.40130484608170897
# Function value: (100, 2)
# Constraint violation: (100, 1)
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
#
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# problem is:
#  # name: BNH
# # n_var: 2
# # n_obj: 2
# # n_constr: 2
#
# Time elapsed for solving problem:  0.17244195938110352  seconds
#
# Evaluation times: 2260
# Best solution found: (100, 2)
# GD 0.40130484608170897
# Function value: (100, 2)
# Constraint violation: (100, 1)
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
#
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# problem is:
#  # name: BNH
# # n_var: 2
# # n_obj: 2
# # n_constr: 2
#
# Time elapsed for solving problem:  0.1687779426574707  seconds
#
# Evaluation times: 2310
# Best solution found: (100, 2)
# GD 0.4006851040181085
# Function value: (100, 2)
# Constraint violation: (100, 1)
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
#
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# problem is:
#  # name: BNH
# # n_var: 2
# # n_obj: 2
# # n_constr: 2
#
# Time elapsed for solving problem:  0.1588897705078125  seconds
#
# Evaluation times: 2360
# Best solution found: (100, 2)
# GD 0.4006851040181085
# Function value: (100, 2)
# Constraint violation: (100, 1)
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
#
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# problem is:
#  # name: BNH
# # n_var: 2
# # n_obj: 2
# # n_constr: 2
#
# Time elapsed for solving problem:  0.19282197952270508  seconds
#
# Evaluation times: 2410
# Best solution found: (100, 2)
# GD 0.390325138813631
# Function value: (100, 2)
# Constraint violation: (100, 1)
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
#
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# problem is:
#  # name: BNH
# # n_var: 2
# # n_obj: 2
# # n_constr: 2
#
# Time elapsed for solving problem:  0.17070984840393066  seconds
#
# Evaluation times: 2460
# Best solution found: (100, 2)
# GD 0.390325138813631
# Function value: (100, 2)
# Constraint violation: (100, 1)
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
#
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# problem is:
#  # name: BNH
# # n_var: 2
# # n_obj: 2
# # n_constr: 2
#
# Time elapsed for solving problem:  0.20105910301208496  seconds
#
# Evaluation times: 2510
# Best solution found: (100, 2)
# GD 0.38194572033721313
# Function value: (100, 2)
# Constraint violation: (100, 1)
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
#
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# problem is:
#  # name: BNH
# # n_var: 2
# # n_obj: 2
# # n_constr: 2
#
# Time elapsed for solving problem:  0.17934823036193848  seconds
#
# Evaluation times: 2560
# Best solution found: (100, 2)
# GD 0.38194572033721313
# Function value: (100, 2)
# Constraint violation: (100, 1)
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
#
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# problem is:
#  # name: BNH
# # n_var: 2
# # n_obj: 2
# # n_constr: 2
#
# Time elapsed for solving problem:  0.18294668197631836  seconds
#
# Evaluation times: 2610
# Best solution found: (100, 2)
# GD 0.40558537279587215
# Function value: (100, 2)
# Constraint violation: (100, 1)
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
#
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# problem is:
#  # name: BNH
# # n_var: 2
# # n_obj: 2
# # n_constr: 2
#
# Time elapsed for solving problem:  0.20827913284301758  seconds
#
# Evaluation times: 2660
# Best solution found: (100, 2)
# GD 0.40558537279587215
# Function value: (100, 2)
# Constraint violation: (100, 1)
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
#
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# problem is:
#  # name: BNH
# # n_var: 2
# # n_obj: 2
# # n_constr: 2
#
# Time elapsed for solving problem:  0.19383502006530762  seconds
#
# Evaluation times: 2710
# Best solution found: (100, 2)
# GD 0.4134414362095509
# Function value: (100, 2)
# Constraint violation: (100, 1)
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
#
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# problem is:
#  # name: BNH
# # n_var: 2
# # n_obj: 2
# # n_constr: 2
#
# Time elapsed for solving problem:  0.21271300315856934  seconds
#
# Evaluation times: 2760
# Best solution found: (100, 2)
# GD 0.4134414362095509
# Function value: (100, 2)
# Constraint violation: (100, 1)
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
#
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# problem is:
#  # name: BNH
# # n_var: 2
# # n_obj: 2
# # n_constr: 2
#
# Time elapsed for solving problem:  0.19538116455078125  seconds
#
# Evaluation times: 2810
# Best solution found: (100, 2)
# GD 0.4206909435801735
# Function value: (100, 2)
# Constraint violation: (100, 1)
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
#
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# problem is:
#  # name: BNH
# # n_var: 2
# # n_obj: 2
# # n_constr: 2
#
# Time elapsed for solving problem:  0.19625091552734375  seconds
#
# Evaluation times: 2860
# Best solution found: (100, 2)
# GD 0.4206909435801735
# Function value: (100, 2)
# Constraint violation: (100, 1)
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
#
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# problem is:
#  # name: BNH
# # n_var: 2
# # n_obj: 2
# # n_constr: 2
#
# Time elapsed for solving problem:  0.22914886474609375  seconds
#
# Evaluation times: 2910
# Best solution found: (100, 2)
# GD 0.42486898101499654
# Function value: (100, 2)
# Constraint violation: (100, 1)
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
#
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# problem is:
#  # name: BNH
# # n_var: 2
# # n_obj: 2
# # n_constr: 2
#
# Time elapsed for solving problem:  0.2009291648864746  seconds
#
# Evaluation times: 2960
# Best solution found: (100, 2)
# GD 0.42486898101499654
# Function value: (100, 2)
# Constraint violation: (100, 1)
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
#
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# problem is:
#  # name: OSY
# # n_var: 6
# # n_obj: 2
# # n_constr: 6
#
# Time elapsed for solving problem:  0.0060460567474365234  seconds
#
# Evaluation times: 10
# Best solution found: (1, 6)
# GD 41.76805351545564
# Function value: (1, 2)
# Constraint violation: (1, 1)
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
#
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# problem is:
#  # name: OSY
# # n_var: 6
# # n_obj: 2
# # n_constr: 6
#
# Time elapsed for solving problem:  0.0036821365356445312  seconds
#
# Evaluation times: 60
# Best solution found: (1, 6)
# GD 41.76805351545564
# Function value: (1, 2)
# Constraint violation: (1, 1)
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
#
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# problem is:
#  # name: OSY
# # n_var: 6
# # n_obj: 2
# # n_constr: 6
#
# Time elapsed for solving problem:  0.008671045303344727  seconds
#
# Evaluation times: 110
# Best solution found: (2, 6)
# GD 41.8760492639973
# Function value: (2, 2)
# Constraint violation: (2, 1)
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
#
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# problem is:
#  # name: OSY
# # n_var: 6
# # n_obj: 2
# # n_constr: 6
#
# Time elapsed for solving problem:  0.008525848388671875  seconds
#
# Evaluation times: 160
# Best solution found: (2, 6)
# GD 41.8760492639973
# Function value: (2, 2)
# Constraint violation: (2, 1)
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
#
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# problem is:
#  # name: OSY
# # n_var: 6
# # n_obj: 2
# # n_constr: 6
#
# Time elapsed for solving problem:  0.013878107070922852  seconds
#
# Evaluation times: 210
# Best solution found: (5, 6)
# GD 48.825027975771874
# Function value: (5, 2)
# Constraint violation: (5, 1)
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
#
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# problem is:
#  # name: OSY
# # n_var: 6
# # n_obj: 2
# # n_constr: 6
#
# Time elapsed for solving problem:  0.013593673706054688  seconds
#
# Evaluation times: 260
# Best solution found: (5, 6)
# GD 48.825027975771874
# Function value: (5, 2)
# Constraint violation: (5, 1)
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
#
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# problem is:
#  # name: OSY
# # n_var: 6
# # n_obj: 2
# # n_constr: 6
#
# Time elapsed for solving problem:  0.03712892532348633  seconds
#
# Evaluation times: 310
# Best solution found: (10, 6)
# GD 48.947018172611834
# Function value: (10, 2)
# Constraint violation: (10, 1)
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
#
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# problem is:
#  # name: OSY
# # n_var: 6
# # n_obj: 2
# # n_constr: 6
#
# Time elapsed for solving problem:  0.021231889724731445  seconds
#
# Evaluation times: 360
# Best solution found: (10, 6)
# GD 48.947018172611834
# Function value: (10, 2)
# Constraint violation: (10, 1)
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
#
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# problem is:
#  # name: OSY
# # n_var: 6
# # n_obj: 2
# # n_constr: 6
#
# Time elapsed for solving problem:  0.028249025344848633  seconds
#
# Evaluation times: 410
# Best solution found: (10, 6)
# GD 43.60001865643304
# Function value: (10, 2)
# Constraint violation: (10, 1)
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
#
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# problem is:
#  # name: OSY
# # n_var: 6
# # n_obj: 2
# # n_constr: 6
#
# Time elapsed for solving problem:  0.028484106063842773  seconds
#
# Evaluation times: 460
# Best solution found: (10, 6)
# GD 43.60001865643304
# Function value: (10, 2)
# Constraint violation: (10, 1)
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
#
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# problem is:
#  # name: OSY
# # n_var: 6
# # n_obj: 2
# # n_constr: 6
#
# Time elapsed for solving problem:  0.0368800163269043  seconds
#
# Evaluation times: 510
# Best solution found: (7, 6)
# GD 37.69621022233838
# Function value: (7, 2)
# Constraint violation: (7, 1)
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
#
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# problem is:
#  # name: OSY
# # n_var: 6
# # n_obj: 2
# # n_constr: 6
#
# Time elapsed for solving problem:  0.03504300117492676  seconds
#
# Evaluation times: 560
# Best solution found: (7, 6)
# GD 37.69621022233838
# Function value: (7, 2)
# Constraint violation: (7, 1)
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
#
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# problem is:
#  # name: OSY
# # n_var: 6
# # n_obj: 2
# # n_constr: 6
#
# Time elapsed for solving problem:  0.04116702079772949  seconds
#
# Evaluation times: 610
# Best solution found: (12, 6)
# GD 36.65241769375985
# Function value: (12, 2)
# Constraint violation: (12, 1)
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
#
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# problem is:
#  # name: OSY
# # n_var: 6
# # n_obj: 2
# # n_constr: 6
#
# Time elapsed for solving problem:  0.041272640228271484  seconds
#
# Evaluation times: 660
# Best solution found: (12, 6)
# GD 36.65241769375985
# Function value: (12, 2)
# Constraint violation: (12, 1)
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
#
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# problem is:
#  # name: OSY
# # n_var: 6
# # n_obj: 2
# # n_constr: 6
#
# Time elapsed for solving problem:  0.0489652156829834  seconds
#
# Evaluation times: 710
# Best solution found: (7, 6)
# GD 20.676128091247886
# Function value: (7, 2)
# Constraint violation: (7, 1)
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
#
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# problem is:
#  # name: OSY
# # n_var: 6
# # n_obj: 2
# # n_constr: 6
#
# Time elapsed for solving problem:  0.0485379695892334  seconds
#
# Evaluation times: 760
# Best solution found: (7, 6)
# GD 20.676128091247886
# Function value: (7, 2)
# Constraint violation: (7, 1)
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
#
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# problem is:
#  # name: OSY
# # n_var: 6
# # n_obj: 2
# # n_constr: 6
#
# Time elapsed for solving problem:  0.0548100471496582  seconds
#
# Evaluation times: 810
# Best solution found: (10, 6)
# GD 21.34103239163713
# Function value: (10, 2)
# Constraint violation: (10, 1)
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
#
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# problem is:
#  # name: OSY
# # n_var: 6
# # n_obj: 2
# # n_constr: 6
#
# ...
# ------------------------------------------------------------
# problem is:
#  # name: WeldedBeam
# # n_var: 4
# # n_obj: 2
# # n_constr: 4
#
# Time elapsed for solving problem:  0.1574418544769287  seconds
#
# Evaluation times: 2410
# Best solution found: (100, 4)
# GD 0.23223869669716213
# Function value: (100, 2)
# Constraint violation: (100, 1)
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
#
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# problem is:
#  # name: WeldedBeam
# # n_var: 4
# # n_obj: 2
# # n_constr: 4
#
# Time elapsed for solving problem:  0.191969633102417  seconds
#
# Evaluation times: 2460
# Best solution found: (100, 4)
# GD 0.23223869669716213
# Function value: (100, 2)
# Constraint violation: (100, 1)
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
#
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# problem is:
#  # name: WeldedBeam
# # n_var: 4
# # n_obj: 2
# # n_constr: 4
#
# Time elapsed for solving problem:  0.1631178855895996  seconds
#
# Evaluation times: 2510
# Best solution found: (100, 4)
# GD 0.29398602705465643
# Function value: (100, 2)
# Constraint violation: (100, 1)
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
#
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# problem is:
#  # name: WeldedBeam
# # n_var: 4
# # n_obj: 2
# # n_constr: 4
#
# Time elapsed for solving problem:  0.16842293739318848  seconds
#
# Evaluation times: 2560
# Best solution found: (100, 4)
# GD 0.29398602705465643
# Function value: (100, 2)
# Constraint violation: (100, 1)
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
#
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# problem is:
#  # name: WeldedBeam
# # n_var: 4
# # n_obj: 2
# # n_constr: 4
#
# Time elapsed for solving problem:  0.19035911560058594  seconds
#
# Evaluation times: 2610
# Best solution found: (100, 4)
# GD 0.19012478917614395
# Function value: (100, 2)
# Constraint violation: (100, 1)
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
#
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# problem is:
#  # name: WeldedBeam
# # n_var: 4
# # n_obj: 2
# # n_constr: 4
#
# Time elapsed for solving problem:  0.17594504356384277  seconds
#
# Evaluation times: 2660
# Best solution found: (100, 4)
# GD 0.19012478917614395
# Function value: (100, 2)
# Constraint violation: (100, 1)
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
#
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# problem is:
#  # name: WeldedBeam
# # n_var: 4
# # n_obj: 2
# # n_constr: 4
#
# Time elapsed for solving problem:  0.20363378524780273  seconds
#
# Evaluation times: 2710
# Best solution found: (100, 4)
# GD 0.11537624885351519
# Function value: (100, 2)
# Constraint violation: (100, 1)
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
#
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# problem is:
#  # name: WeldedBeam
# # n_var: 4
# # n_obj: 2
# # n_constr: 4
#
# Time elapsed for solving problem:  0.17644405364990234  seconds
#
# Evaluation times: 2760
# Best solution found: (100, 4)
# GD 0.11537624885351519
# Function value: (100, 2)
# Constraint violation: (100, 1)
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
#
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# problem is:
#  # name: WeldedBeam
# # n_var: 4
# # n_obj: 2
# # n_constr: 4
#
# Time elapsed for solving problem:  0.18841767311096191  seconds
#
# Evaluation times: 2810
# Best solution found: (100, 4)
# GD 0.11463392328602463
# Function value: (100, 2)
# Constraint violation: (100, 1)
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
#
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# problem is:
#  # name: WeldedBeam
# # n_var: 4
# # n_obj: 2
# # n_constr: 4
#
# Time elapsed for solving problem:  0.20288324356079102  seconds
#
# Evaluation times: 2860
# Best solution found: (100, 4)
# GD 0.11463392328602463
# Function value: (100, 2)
# Constraint violation: (100, 1)
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
#
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# problem is:
#  # name: WeldedBeam
# # n_var: 4
# # n_obj: 2
# # n_constr: 4
#
# Time elapsed for solving problem:  0.19209027290344238  seconds
#
# Evaluation times: 2910
# Best solution found: (100, 4)
# GD 0.10912431527540013
# Function value: (100, 2)
# Constraint violation: (100, 1)
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
#
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# problem is:
#  # name: WeldedBeam
# # n_var: 4
# # n_obj: 2
# # n_constr: 4
#
# Time elapsed for solving problem:  0.21576881408691406  seconds
#
# Evaluation times: 2960
# Best solution found: (100, 4)
# GD 0.10912431527540013
# Function value: (100, 2)
# Constraint violation: (100, 1)
# /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II
# Creation of the directory /Users/wuyoscar/Documents/Project/MOOP/Loop files/algorithmns/NSGA-II/Result/Algorithmn_Result/NAGA-II failed
# ------------------------------------------------------------
# BNH {'1410': 0.3404297944868695, '1460': 0.3404297944868695, '1710': 0.3426728407580243, '1760': 0.3426728407580243, '1810': 0.3606750525576992, '1860': 0.3606750525576992, '1610': 0.36121723435568515, '1660': 0.36121723435568515, '1510': 0.36420236333221373, '1560': 0.36420236333221373, '1910': 0.37742743354693753, '1960': 0.37742743354693753, '2010': 0.3787495601760043, '2060': 0.3787495601760043, '2110': 0.38157435771048226, '2160': 0.38157435771048226, '2510': 0.38194572033721313, '2560': 0.38194572033721313, '1210': 0.38473508395789335, '1260': 0.38473508395789335, '1310': 0.3851667151545989, '1360': 0.3851667151545989, '1110': 0.38850645832948205, '1160': 0.38850645832948205, '2410': 0.390325138813631, '2460': 0.390325138813631, '2310': 0.4006851040181085, '2360': 0.4006851040181085, '2210': 0.40130484608170897, '2260': 0.40130484608170897, '1010': 0.40257121167643417, '1060': 0.40257121167643417, '2610': 0.40558537279587215, '2660': 0.40558537279587215, '910': 0.4066756614383871, '960': 0.4066756614383871, '2710': 0.4134414362095509, '2760': 0.4134414362095509, '2810': 0.4206909435801735, '2860': 0.4206909435801735, '2910': 0.42486898101499654, '2960': 0.42486898101499654, '810': 0.43518503269982056, '860': 0.43518503269982056, '610': 0.46565411425995046, '660': 0.46565411425995046, '710': 0.46872616811211243, '760': 0.46872616811211243, '510': 0.4712777986435834, '560': 0.4712777986435834, '410': 0.5175951294780777, '460': 0.5175951294780777, '310': 0.5333166168074782, '360': 0.5333166168074782, '210': 0.566634510627196, '260': 0.566634510627196, '110': 0.6185397605304154, '160': 0.6185397605304154, '10': 0.6853353204814265, '60': 0.6853353204814265}
#
#
