# %%
from problems import *

# %% [markdown]
# ## 1. problems

# %%
aval_problems()
# Out:
# The multiple obejective problems:
# ----------------------------------------
#
#
# binh_and_korn_Problem
#
#
# changkong_and_haimes_problem
#
#
# test_problem
#
#
# constr_ex_problem
#
# -----------------------
#
# Call problem by name
#
#
# *****
#
# split_X(given_design_space,given_problem):
#
# feasible_X,infeasible_X, feasible_F,infeasible_F,feasible_G,infeasible_G
# 'Updating more problems'

# %%
ch_problem = changkong_and_haimes_problem()
print(ch_problem)
# Out:
# # name: changkong_and_haimes_problem
# # n_var: 2
# # n_obj: 2
# # n_constr: 2

# %%
#given design space 
#given problem

#split_X(X, ch_problem)

rng = np.random.default_rng(seed=22)

x = 40*rng.random((1000,1))-20 #[-20,20]
y = 40*rng.random((1000,1))-20 #[-20,20]

X = np.concatenate([x,y],axis=1)
print('max var_1 is {}, min var_1 is {} :'.format(np.max(x), np.min(x)))
print('max var_2 is {}, max var_2 is {} :'.format(np.max(y), np.min(x)))
print('\n-----------\n')

print(X.shape[:5])
print('\n-----------')
print(X[:10])
# Out:
# max var_1 is 19.941507567496387, min var_1 is -19.938795014826102 :
# max var_2 is 19.962123772810962, max var_2 is -19.938795014826102 :
#
# -----------
#
# (1000, 2)
#
# -----------
# [[ -5.34612338   0.56182381]
#  [-12.02818482   6.11893202]
#  [-16.45766507  13.74338852]
#  [  6.1276675   -6.45175577]
#  [ -1.62651821 -16.11185439]
#  [ 19.50702476 -14.20837377]
#  [ 14.06272279  19.19617781]
#  [ 13.47845293  -2.71329993]
#  [-17.9424493    4.55166775]
#  [  2.21380621   1.60514857]]

# %%
feasible_X,infeasible_X, feasible_F,infeasible_F,feasible_G,infeasible_G = split_X(X, ch_problem)
# Out:
# 1000 data points and 2 n_vars in Receive X:
#
# 167--feasible
# 833--infesiable
#
# *****
#
# plot_problem(X, problem)

# %%
plot_problem(X, ch_problem)
# Out:
# 1000 data points and 2 n_vars in Receive X:
#
# 167--feasible
# 833--infesiable
#
# *****
#
# plot_problem(X, problem)

# %%
from algorithms import *
# Out:
# algorithmn:
# nsga2
#
# ******
#
# n_evals, F, cv = gen_res(res)
# plot_cv(res)
# plot_hv(res, ref_point =np.array([1.0, 1.0]))
# plot_cc(res,problem, X ,algorithmns_name = 'Algorithmn')

# %%
res = nsga2(ch_problem)
# Out:
# =====================================================================================
# n_gen |  n_eval |   cv (min)   |   cv (avg)   |  n_nds  |     eps      |  indicator
# =====================================================================================
#     1 |     100 |  0.00000E+00 |  1.27362E+02 |       8 |            - |            -
#     2 |     200 |  0.00000E+00 |  1.15281E+01 |      16 |  0.024880199 |        ideal
#     3 |     300 |  0.00000E+00 |  0.00000E+00 |      25 |  0.030716681 |            f
#     4 |     400 |  0.00000E+00 |  0.00000E+00 |      39 |  0.086354867 |        ideal
#     5 |     500 |  0.00000E+00 |  0.00000E+00 |      55 |  0.047843525 |        nadir
#     6 |     600 |  0.00000E+00 |  0.00000E+00 |      78 |  0.008134541 |        ideal
#     7 |     700 |  0.00000E+00 |  0.00000E+00 |     100 |  0.020989861 |        ideal
#     8 |     800 |  0.00000E+00 |  0.00000E+00 |     100 |  0.003601572 |            f
#     9 |     900 |  0.00000E+00 |  0.00000E+00 |     100 |  0.002513852 |        ideal
#    10 |    1000 |  0.00000E+00 |  0.00000E+00 |     100 |  0.006493542 |        ideal
#    11 |    1100 |  0.00000E+00 |  0.00000E+00 |     100 |  0.004524906 |        ideal
#    12 |    1200 |  0.00000E+00 |  0.00000E+00 |     100 |  0.001420661 |            f
#    13 |    1300 |  0.00000E+00 |  0.00000E+00 |     100 |  0.001753576 |            f
#    14 |    1400 |  0.00000E+00 |  0.00000E+00 |     100 |  0.001169715 |            f
#    15 |    1500 |  0.00000E+00 |  0.00000E+00 |     100 |  0.001532540 |            f
#    16 |    1600 |  0.00000E+00 |  0.00000E+00 |     100 |  0.001173980 |            f
#    17 |    1700 |  0.00000E+00 |  0.00000E+00 |     100 |  0.001450084 |            f
#    18 |    1800 |  0.00000E+00 |  0.00000E+00 |     100 |  0.001001919 |            f
#    19 |    1900 |  0.00000E+00 |  0.00000E+00 |     100 |  0.001516341 |            f
#    20 |    2000 |  0.00000E+00 |  0.00000E+00 |     100 |  0.039003104 |        nadir
#    21 |    2100 |  0.00000E+00 |  0.00000E+00 |     100 |  0.001026814 |            f
#    22 |    2200 |  0.00000E+00 |  0.00000E+00 |     100 |  0.007063398 |        nadir
#    23 |    2300 |  0.00000E+00 |  0.00000E+00 |     100 |  0.001517123 |            f
#    24 |    2400 |  0.00000E+00 |  0.00000E+00 |     100 |  0.011382175 |        nadir
#    25 |    2500 |  0.00000E+00 |  0.00000E+00 |     100 |  0.001766595 |            f
#    26 |    2600 |  0.00000E+00 |  0.00000E+00 |     100 |  0.001398477 |            f
#    27 |    2700 |  0.00000E+00 |  0.00000E+00 |     100 |  0.001257466 |            f
#    28 |    2800 |  0.00000E+00 |  0.00000E+00 |     100 |  0.001569611 |            f
#    29 |    2900 |  0.00000E+00 |  0.00000E+00 |     100 |  0.007665098 |        nadir
#    30 |    3000 |  0.00000E+00 |  0.00000E+00 |     100 |  0.001697488 |            f
#    31 |    3100 |  0.00000E+00 |  0.00000E+00 |     100 |  0.001148125 |            f
#    32 |    3200 |  0.00000E+00 |  0.00000E+00 |     100 |  0.001253046 |            f
#    33 |    3300 |  0.00000E+00 |  0.00000E+00 |     100 |  0.001242093 |            f
#    34 |    3400 |  0.00000E+00 |  0.00000E+00 |     100 |  0.001571537 |            f
#    35 |    3500 |  0.00000E+00 |  0.00000E+00 |     100 |  0.001387609 |            f
#    36 |    3600 |  0.00000E+00 |  0.00000E+00 |     100 |  0.001864886 |            f
#    37 |    3700 |  0.00000E+00 |  0.00000E+00 |     100 |  0.001351190 |            f
#    38 |    3800 |  0.00000E+00 |  0.00000E+00 |     100 |  0.001516093 |            f
#    39 |    3900 |  0.00000E+00 |  0.00000E+00 |     100 |  0.001580479 |            f
#    40 |    4000 |  0.00000E+00 |  0.00000E+00 |     100 |  0.001121392 |            f
#    41 |    4100 |  0.00000E+00 |  0.00000E+00 |     100 |  0.001255444 |            f
#    42 |    4200 |  0.00000E+00 |  0.00000E+00 |     100 |  0.001392682 |            f
#    43 |    4300 |  0.00000E+00 |  0.00000E+00 |     100 |  0.001528601 |            f
#    44 |    4400 |  0.00000E+00 |  0.00000E+00 |     100 |  0.001117108 |            f
#    45 |    4500 |  0.00000E+00 |  0.00000E+00 |     100 |  0.001737696 |            f
#    46 |    4600 |  0.00000E+00 |  0.00000E+00 |     100 |  0.001566029 |            f
#    47 |    4700 |  0.00000E+00 |  0.00000E+00 |     100 |  0.001451890 |            f
#    48 |    4800 |  0.00000E+00 |  0.00000E+00 |     100 |  0.001644474 |            f
#    49 |    4900 |  0.00000E+00 |  0.00000E+00 |     100 |  0.001218739 |            f
#    50 |    5000 |  0.00000E+00 |  0.00000E+00 |     100 |  0.001374722 |            f
#    51 |    5100 |  0.00000E+00 |  0.00000E+00 |     100 |  0.001405794 |            f
#    52 |    5200 |  0.00000E+00 |  0.00000E+00 |     100 |  0.001243281 |            f
#    53 |    5300 |  0.00000E+00 |  0.00000E+00 |     100 |  0.001488296 |            f
#    54 |    5400 |  0.00000E+00 |  0.00000E+00 |     100 |  0.001240756 |            f
#    55 |    5500 |  0.00000E+00 |  0.00000E+00 |     100 |  0.001602966 |            f
#    56 |    5600 |  0.00000E+00 |  0.00000E+00 |     100 |  0.001530885 |            f
#    57 |    5700 |  0.00000E+00 |  0.00000E+00 |     100 |  0.001789364 |            f
#    58 |    5800 |  0.00000E+00 |  0.00000E+00 |     100 |  0.001280146 |            f
#    59 |    5900 |  0.00000E+00 |  0.00000E+00 |     100 |  0.001629938 |            f
#    60 |    6000 |  0.00000E+00 |  0.00000E+00 |     100 |  0.001245830 |            f
#
# Time elapsed for solving problem:  0.5783710479736328  seconds
#
# Generations 60
# Design space (100, 2)
# Object values space (100, 2)
# Constraint values (100, 2)
# Aggregated constraint violation (100, 1)
# Final population object (100,)

# %%
n_evals, F, cv = gen_res(res)

# %%
plot_cc(res,ch_problem, X ,algorithmns_name = 'Algorithmn')
# Out:
# 1000 data points and 2 n_vars in Receive X:
#
# 167--feasible
# 833--infesiable
#
# *****
#
# plot_problem(X, problem)
