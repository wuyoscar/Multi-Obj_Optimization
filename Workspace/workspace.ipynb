# %%
import pandas as pd 
import pygmo as pg
import numpy as np

# %%
df = pd.read_csv('/Users/wuyoscar/Documents/Project/MOOP/Result/50Million-Result')
df_2 = pd.read_csv('/Users/wuyoscar/Documents/Project/MOOP/Result/10Million-Result')
df_3 = pd.read_csv('/Users/wuyoscar/Documents/Project/MOOP/Result/result_5NOV')

# %%
Problem_list = list(df.Problem.unique())
print(len(Problem_list))
result_50M = df.sort_values('Problem').reset_index(drop =True)
result_10M = df_2.sort_values('Problem').reset_index(drop =True)
result_Other= df_3.sort_values('Problem').reset_index(drop =True)
# Out:
# 10

# %%
#get all results
result_all = pd.concat([result_50M,result_10M,result_Other])
result_all.to_csv('result_all')

# %%
#/Users/wuyoscar/Documents/Project/MOOP
import os 
path_o = os.path.dirname(os.getcwd())
path_o
# Out:
# '/Users/wuyoscar/Documents/Project/MOOP'

# %%
result_all = pd.read_csv('/Users/wuyoscar/Documents/Project/MOOP/Result/result_all')
result_all.loc[:,'path'] = result_all.path.str[22:].values
result_all.loc[:,'image_location'] = result_all.image_location.str[22:].values
result_all = result_all.iloc[:,1:]
result_all.head(5)

print(f'total recrod {len(result_all)}')
# Out:
# total recrod 962

# %% [markdown]
# # Kur1

# %%
Kur1 = result_all.loc[result_all['Problem'] =='KUR1'].reset_index(drop=True)

# %%
Kur1_2 = Kur1[Kur1.n_variables==2]
Kur1_3 = Kur1[Kur1.n_variables==3]
Kur1_4 = Kur1[Kur1.n_variables==4]
Kur1_5 = Kur1[Kur1.n_variables==5]

# %%
import numpy as np 
array_list = []
for i in Kur1_2.path:
    path = os.path.join(path_o, i )
    f = np.loadtxt(path)
    array_list.append(f)
all_f = np.concatenate(array_list)
ndf, dl, dc, ndr = pg.fast_non_dominated_sorting(all_f)
non_donmiated_solution = all_f[ndf[0]]
print(f"there are {all_f.shape[0]} solution if concat individual jobs. Found {non_donmiated_solution.shape[0]} non-dominated set among them")
np.savetxt('/Users/wuyoscar/Documents/Project/MOOP/Result/result_factory/Bench/kur1_2_pf' ,non_donmiated_solution)
# Out:
# there are 6714 solution if concat individual jobs. Found 3304 non-dominated set among them

# %%
array_list = []
for i in Kur1_3.path:
    path = os.path.join(path_o, i )
    f = np.loadtxt(path)
    array_list.append(f)
all_f = np.concatenate(array_list)
ndf, dl, dc, ndr = pg.fast_non_dominated_sorting(all_f)
non_donmiated_solution = all_f[ndf[0]]
print(f"there are {all_f.shape[0]} solution if concat individual jobs. Found {non_donmiated_solution.shape[0]} non-dominated set among them")
np.savetxt('/Users/wuyoscar/Documents/Project/MOOP/Result/result_factory/Bench/kur1_3_pf' ,non_donmiated_solution)
# Out:
# there are 6640 solution if concat individual jobs. Found 2822 non-dominated set among them

# %%
array_list = []
for i in Kur1_4.path:
    path = os.path.join(path_o, i )
    f = np.loadtxt(path)
    array_list.append(f)
all_f = np.concatenate(array_list)
ndf, dl, dc, ndr = pg.fast_non_dominated_sorting(all_f)
non_donmiated_solution = all_f[ndf[0]]
print(f"there are {all_f.shape[0]} solution if concat individual jobs. Found {non_donmiated_solution.shape[0]} non-dominated set among them")
np.savetxt('/Users/wuyoscar/Documents/Project/MOOP/Result/result_factory/Bench/kur1_4_pf' ,non_donmiated_solution)
# Out:
# there are 6653 solution if concat individual jobs. Found 2431 non-dominated set among them

# %%
array_list = []
for i in Kur1_5.path:
    path = os.path.join(path_o, i )
    f = np.loadtxt(path)
    array_list.append(f)
all_f = np.concatenate(array_list)
ndf, dl, dc, ndr = pg.fast_non_dominated_sorting(all_f)
non_donmiated_solution = all_f[ndf[0]]
print(f"there are {all_f.shape[0]} solution if concat individual jobs. Found {non_donmiated_solution.shape[0]} non-dominated set among them")
np.savetxt('/Users/wuyoscar/Documents/Project/MOOP/Result/result_factory/Bench/kur1_5_pf' ,non_donmiated_solution)
# Out:
# there are 6634 solution if concat individual jobs. Found 2299 non-dominated set among them

# %%
LTDZ1_R = result_all.loc[result_all['Problem'] =='LTDZ1'].reset_index(drop=True)

array_list = []
for i in LTDZ1_R.path:
    path = os.path.join(path_o, i )
    f = np.loadtxt(path)
    array_list.append(f)
all_f = np.concatenate(array_list)
ndf, dl, dc, ndr = pg.fast_non_dominated_sorting(all_f)
non_donmiated_solution = all_f[ndf[0]]
print(f"there are {all_f.shape[0]} solution if concat individual jobs. Found {non_donmiated_solution.shape[0]} non-dominated set among them")
np.savetxt('/Users/wuyoscar/Documents/Project/MOOP/Result/result_factory/Bench/ltdz1_pf' ,non_donmiated_solution)
# Out:
# there are 7065 solution if concat individual jobs. Found 5042 non-dominated set among them

# %%
sk2 = result_all.loc[result_all['Problem'] =='SK2'].reset_index(drop=True)
array_list=[]
for i in sk2.path:
    path = os.path.join(path_o, i )
    f = np.loadtxt(path)
    array_list.append(f)
all_f = np.concatenate(array_list)
ndf, dl, dc, ndr = pg.fast_non_dominated_sorting(all_f)
non_donmiated_solution = all_f[ndf[0]]
print(f"there are {all_f.shape[0]} solution if concat individual jobs. Found {non_donmiated_solution.shape[0]} non-dominated set among them")
np.savetxt('/Users/wuyoscar/Documents/Project/MOOP/Result/result_factory/Bench/sk2_pf' ,non_donmiated_solution)
# Out:
# there are 6708 solution if concat individual jobs. Found 1524 non-dominated set among them

# %%
sk2_typo = result_all.loc[result_all['Problem'] =='SK2_TYPO'].reset_index(drop=True)
array_list=[]
for i in sk2_typo.path:
    path = os.path.join(path_o, i )
    f = np.loadtxt(path)
    array_list.append(f)
all_f = np.concatenate(array_list)
ndf, dl, dc, ndr = pg.fast_non_dominated_sorting(all_f)
non_donmiated_solution = all_f[ndf[0]]
print(f"there are {all_f.shape[0]} solution if concat individual jobs. Found {non_donmiated_solution.shape[0]} non-dominated set among them")
np.savetxt('/Users/wuyoscar/Documents/Project/MOOP/Result/result_factory/Bench/sk2_typo_pf' ,non_donmiated_solution)
# Out:
# there are 6729 solution if concat individual jobs. Found 1520 non-dominated set among them

# %%
tkly1 = result_all.loc[result_all['Problem'] =='TKLY1'].reset_index(drop=True)
array_list=[]
for i in tkly1.path:
    path = os.path.join(path_o, i )
    f = np.loadtxt(path)
    array_list.append(f)
all_f = np.concatenate(array_list)
ndf, dl, dc, ndr = pg.fast_non_dominated_sorting(all_f)
non_donmiated_solution = all_f[ndf[0]]
print(f"there are {all_f.shape[0]} solution if concat individual jobs. Found {non_donmiated_solution.shape[0]} non-dominated set among them")
np.savetxt('/Users/wuyoscar/Documents/Project/MOOP/Result/result_factory/Bench/tkly1_pf' ,non_donmiated_solution)
# Out:
# there are 6824 solution if concat individual jobs. Found 824 non-dominated set among them

# %%
vu1 = result_all.loc[result_all['Problem'] =='VU1'].reset_index(drop=True)
array_list=[]
for i in vu1.path:
    path = os.path.join(path_o, i )
    f = np.loadtxt(path)
    array_list.append(f)
all_f = np.concatenate(array_list)
ndf, dl, dc, ndr = pg.fast_non_dominated_sorting(all_f)
non_donmiated_solution = all_f[ndf[0]]
print(f"there are {all_f.shape[0]} solution if concat individual jobs. Found {non_donmiated_solution.shape[0]} non-dominated set among them")
np.savetxt('/Users/wuyoscar/Documents/Project/MOOP/Result/result_factory/Bench/vu1_pf' ,non_donmiated_solution)
# Out:
# there are 7053 solution if concat individual jobs. Found 4218 non-dominated set among them

# %%
vu2 = result_all.loc[result_all['Problem'] =='VU2'].reset_index(drop=True)
array_list=[]
for i in vu2.path:
    path = os.path.join(path_o, i )
    f = np.loadtxt(path)
    array_list.append(f)
all_f = np.concatenate(array_list)
ndf, dl, dc, ndr = pg.fast_non_dominated_sorting(all_f)
non_donmiated_solution = all_f[ndf[0]]
print(f"there are {all_f.shape[0]} solution if concat individual jobs. Found {non_donmiated_solution.shape[0]} non-dominated set among them")
np.savetxt('/Users/wuyoscar/Documents/Project/MOOP/Result/result_factory/Bench/vu2_pf' ,non_donmiated_solution)
# Out:
# there are 7056 solution if concat individual jobs. Found 6592 non-dominated set among them

# %%
zdt1_10  =result_all.loc[(result_all['Problem'] =='ZDT1') & (result_all['n_variables'] ==10)].reset_index(drop=True)
array_list=[]
for i in zdt1_10.path:
    path = os.path.join(path_o, i )
    f = np.loadtxt(path)
    array_list.append(f)
all_f = np.concatenate(array_list)
ndf, dl, dc, ndr = pg.fast_non_dominated_sorting(all_f)
non_donmiated_solution = all_f[ndf[0]]
print(f"there are {all_f.shape[0]} solution if concat individual jobs. Found {non_donmiated_solution.shape[0]} non-dominated set among them")
np.savetxt('/Users/wuyoscar/Documents/Project/MOOP/Result/result_factory/Bench/zdt1_10_pf' ,non_donmiated_solution)
# Out:
# there are 6909 solution if concat individual jobs. Found 4224 non-dominated set among them

# %%
zdt1_20  =result_all.loc[(result_all['Problem'] =='ZDT1') & (result_all['n_variables'] ==20)].reset_index(drop=True)
array_list=[]
for i in zdt1_20.path:
    path = os.path.join(path_o, i )
    f = np.loadtxt(path)
    array_list.append(f)
all_f = np.concatenate(array_list)
ndf, dl, dc, ndr = pg.fast_non_dominated_sorting(all_f)
non_donmiated_solution = all_f[ndf[0]]
print(f"there are {all_f.shape[0]} solution if concat individual jobs. Found {non_donmiated_solution.shape[0]} non-dominated set among them")
np.savetxt('/Users/wuyoscar/Documents/Project/MOOP/Result/result_factory/Bench/zdt1_20_pf' ,non_donmiated_solution)
# Out:
# there are 6773 solution if concat individual jobs. Found 3115 non-dominated set among them

# %%
zdt2_10  =result_all.loc[(result_all['Problem'] =='ZDT2') & (result_all['n_variables'] ==10)].reset_index(drop=True)
array_list=[]
for i in zdt2_10.path:
    path = os.path.join(path_o, i )
    f = np.loadtxt(path)
    array_list.append(f)
all_f = np.concatenate(array_list)
ndf, dl, dc, ndr = pg.fast_non_dominated_sorting(all_f)
non_donmiated_solution = all_f[ndf[0]]
print(f"there are {all_f.shape[0]} solution if concat individual jobs. Found {non_donmiated_solution.shape[0]} non-dominated set among them")
np.savetxt('/Users/wuyoscar/Documents/Project/MOOP/Result/result_factory/Bench/zdt2_10_pf' ,non_donmiated_solution)
# Out:
# there are 6854 solution if concat individual jobs. Found 5214 non-dominated set among them

# %%
zdt2_20  =result_all.loc[(result_all['Problem'] =='ZDT2') & (result_all['n_variables'] ==20)].reset_index(drop=True)
array_list=[]
for i in zdt2_20.path:
    path = os.path.join(path_o, i )
    f = np.loadtxt(path)
    array_list.append(f)
all_f = np.concatenate(array_list)
ndf, dl, dc, ndr = pg.fast_non_dominated_sorting(all_f)
non_donmiated_solution = all_f[ndf[0]]
print(f"there are {all_f.shape[0]} solution if concat individual jobs. Found {non_donmiated_solution.shape[0]} non-dominated set among them")
np.savetxt('/Users/wuyoscar/Documents/Project/MOOP/Result/result_factory/Bench/zdt2_20_pf' ,non_donmiated_solution)
# Out:
# there are 6592 solution if concat individual jobs. Found 3860 non-dominated set among them

# %%
zdt3_10  =result_all.loc[(result_all['Problem'] =='ZDT3') & (result_all['n_variables'] ==10)].reset_index(drop=True)
array_list=[]
for i in zdt3_10.path:
    path = os.path.join(path_o, i )
    f = np.loadtxt(path)
    array_list.append(f)
all_f = np.concatenate(array_list)
ndf, dl, dc, ndr = pg.fast_non_dominated_sorting(all_f)
non_donmiated_solution = all_f[ndf[0]]
print(f"there are {all_f.shape[0]} solution if concat individual jobs. Found {non_donmiated_solution.shape[0]} non-dominated set among them")
np.savetxt('/Users/wuyoscar/Documents/Project/MOOP/Result/result_factory/Bench/zdt3_10_pf' ,non_donmiated_solution)
# Out:
# there are 6817 solution if concat individual jobs. Found 4473 non-dominated set among them

# %%
zdt3_20  =result_all.loc[(result_all['Problem'] =='ZDT3') & (result_all['n_variables'] ==20)].reset_index(drop=True)
array_list=[]
for i in zdt3_20.path:
    path = os.path.join(path_o, i )
    f = np.loadtxt(path)
    array_list.append(f)
all_f = np.concatenate(array_list)
ndf, dl, dc, ndr = pg.fast_non_dominated_sorting(all_f)
non_donmiated_solution = all_f[ndf[0]]
print(f"there are {all_f.shape[0]} solution if concat individual jobs. Found {non_donmiated_solution.shape[0]} non-dominated set among them")
np.savetxt('/Users/wuyoscar/Documents/Project/MOOP/Result/result_factory/Bench/zdt3_20_pf' ,non_donmiated_solution)
# Out:
# there are 6669 solution if concat individual jobs. Found 3286 non-dominated set among them

# %%
import requests 
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import NoSuchElementException
from time import sleep
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/tc/s1vsgctn4gn_n76ylgwmdwrw0000gn/T/ipykernel_33137/3549101595.py in <module>
# ----> 1 import requests
#       2 from bs4 import BeautifulSoup
#       3 from selenium import webdriver
#       4 from selenium.webdriver.common.keys import Keys
#       5 from selenium.common.exceptions import NoSuchElementException
#
# ModuleNotFoundError: No module named 'requests'

# %%
search_input = 'Jianxin' +' Deakin'

driver = webdriver.Chrome()
driver.get("https://scholar.google.com")
#google schloar seach input
#search = driver.find_element_by_id('gs_hdr_tsi')
search = driver.find_element_by_css_selector('input[name= "q"]')

search.send_keys(search_input)# search professor name
search.send_keys(Keys.RETURN) #return result
sleep(5)
#if professor has profile page

try:
    profile_url = driver.find_element_by_css_selector('h4.gs_rt2>a').get_attribute('href')
    driver.get(profile_url) # get profile page
    sleep(5)
    #use soup to get content on profile page
    webpage_response = requests.get(profile_url, 'html.parsers')
    webpage = BeautifulSoup(webpage_response.content, "html.parser")
    #get citation information and store in list
    citation = [i.string for i in webpage.find_all('td', {'class':"gsc_rsb_std"})]
    
#if professor has no such profile page
except NoSuchElementException:
    citation = ['na' for i in range(6)] 
    pass
print(citation)
# Out:
# /var/folders/tc/s1vsgctn4gn_n76ylgwmdwrw0000gn/T/ipykernel_13347/3319657275.py:7: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search = driver.find_element_by_css_selector('input[name= "q"]')
# /var/folders/tc/s1vsgctn4gn_n76ylgwmdwrw0000gn/T/ipykernel_13347/3319657275.py:15: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   profile_url = driver.find_element_by_css_selector('h4.gs_rt2>a').get_attribute('href')
# ['1833', '1455', '23', '20', '48', '42']

# %%
result_add_image = result_all[result_all['Iteration'] ==100000].reset_index(drop=True)

# %%
import glob 

for a, b, c in os.walk('/Users/wuyoscar/Documents/Project/MOOP/Result/result_factory/Bench'):
    for cc in c:
        bench_path = os.path.join(a,cc)
        paretofront = np.loadtxt(bench_path)
        F = paretofront
        plt.figure(figsize=(7, 5))
        plt.scatter(F[:, 0], F[:, 1], s=30, facecolors='none', edgecolors='blue')
        plt.title(f'{cc} -- paretofront shape {paretofront.shape[0]}')
        image_path = os.path.join(os.getcwd(),cc)
        plt.savefig(f"{image_path}")
